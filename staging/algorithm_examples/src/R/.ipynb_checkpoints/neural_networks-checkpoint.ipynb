# %%
# import h2o lib and allow it to use max. threads
library(h2o)
h2o.init(nthreads = -1)
# Out:
# ----------------------------------------------------------------------
#
# Your next step is to start H2O:
#     > h2o.init()
#
# For H2O package documentation, ask for help:
#     > ??h2o
#
# After starting H2O, you can use the Web UI at http://localhost:54321
# For more information visit http://docs.h2o.ai
#
# ----------------------------------------------------------------------
#
#
# Attaching package: ‘h2o’
#
# The following objects are masked from ‘package:stats’:
#
#     cor, sd, var
#
# The following objects are masked from ‘package:base’:
#
#     &&, %*%, %in%, ||, apply, as.factor, as.numeric, colnames,
#     colnames<-, ifelse, is.character, is.factor, is.numeric, log,
#     log10, log1p, log2, round, signif, trunc
#  Connection successful!
#
# R is connected to the H2O cluster:
#     H2O cluster uptime:         26 minutes 44 seconds
#     H2O cluster version:        3.10.4.3
#     H2O cluster version age:    8 days
#     H2O cluster name:           H2O_started_from_R_phall_tfq626
#     H2O cluster total nodes:    1
#     H2O cluster total memory:   3.01 GB
#     H2O cluster total cores:    8
#     H2O cluster allowed cores:  8
#     H2O cluster healthy:        TRUE
#     H2O Connection ip:          localhost
#     H2O Connection port:        54321
#     H2O Connection proxy:       NA
#     H2O Internal Security:      FALSE
#     R Version:                  R version 3.3.2 (2016-10-31)

# %%
# location of clean data file
path <- "https://raw.githubusercontent.com/h2oai/app-consumer-loan/master/data/loan.csv"

# %%
# import file
frame <- h2o.importFile(path)

# strings automatically parsed as enums (categorical)
# numbers automatically parsed as numeric
# bad_loan is numeric, but categorical
frame$bad_loan <- as.factor(frame$bad_loan)
# Out:
#   |======================================================================| 100%

# %%
# find missing numeric and impute
for (name in names(frame)) {
  if (any(is.na(frame[name]))) {
      h2o.impute(frame, name, "median")
  }
}

# %%
h2o.describe(frame) # summarize table, check for missing
# Out:
#    Label                 Type Missing Zeros  PosInf NegInf Min  Max
# 1  loan_amnt             int  0       0      0      0      500  35000
# 2  term                  enum 0       129950 0      0      0    1
# 3  int_rate              real 0       0      0      0      5.42 26.06
# 4  emp_length            int  0       14248  0      0      0    10
# 5  home_ownership        enum 0       1      0      0      0    5
# 6  annual_inc            real 0       0      0      0      1896 7141778
# 7  purpose               enum 0       2842   0      0      0    13
# 8  addr_state            enum 0       413    0      0      0    49
# 9  dti                   real 0       270    0      0      0    39.99
# 10 delinq_2yrs           int  0       139488 0      0      0    29
# 11 revol_util            real 0       1562   0      0      0    150.7
# 12 total_acc             int  0       0      0      0      1    118
# 13 bad_loan              enum 0       133971 0      0      0    1
# 14 longest_credit_length int  0       11     0      0      0    65
# 15 verification_status   enum 0       59155  0      0      0    1
#    Mean              Sigma             Cardinality
# 1  13074.1691414563  7993.55618873467  NA
# 2  0.207559135785154 0.405560530549521 2
# 3  13.7159040655662  4.39193987054581  NA
# 4  5.69552464524627  3.54667110307881  NA
# 5  NA                NA                6
# 6  71915.404262777   59070.2198125624  NA
# 7  NA                NA                14
# 8  NA                NA                50
# 9  15.8815301212902  7.58766822419254  NA
# 10 0.227316799502399 0.694113124115403 NA
# 11 54.081198082775   25.2705517123563  NA
# 12 24.5794544689518  11.6841759724766  NA
# 13 0.183038899424954 0.386699589607887 2
# 14 14.8541225828877  6.94712784863357  NA
# 15 0.639270186051333 0.480213724833117 2

# %%
# assign target and inputs
y <- 'bad_loan'
X <- names(frame)[names(frame) != y]
print(y)
print(X)
# Out:
# [1] "bad_loan"
#  [1] "loan_amnt"             "term"                  "int_rate"
#  [4] "emp_length"            "home_ownership"        "annual_inc"
#  [7] "purpose"               "addr_state"            "dti"
# [10] "delinq_2yrs"           "revol_util"            "total_acc"
# [13] "longest_credit_length" "verification_status"

# %%
# split into training and valid
split <- h2o.splitFrame(frame, ratios = 0.7)
train <- split[[1]]
valid <- split[[2]]

# %%
# neural network

# train
loan_nn <- h2o.deeplearning(
    x = X,
    y = y,
    training_frame = train,
    validation_frame = valid,
    epochs = 50,                     # read over the data 50 times, but in mini-batches
    hidden = c(100),                 # 100 hidden units in 1 hidden layer
    input_dropout_ratio = 0.2,       # randomly drop 20% of inputs for each iteration, helps w/ generalization
    hidden_dropout_ratios = c(0.05), # randomly set 5% of hidden weights to 0 each iteration, helps w/ generalization
    activation = "TanhWithDropout",  # bounded activation function that allows for dropout, tanh, more stable
    l1 = 0.001,                      # L1 penalty can help generalization   
    l2 = 0.01,                       # L2 penalty can increase stability in presence of highly correlated inputs
    adaptive_rate = TRUE,            # adjust magnitude of weight updates automatically (+stability, +accuracy)
    stopping_rounds = 5,             # stop after validation error does not decrease for 5 iterations
    score_each_iteration = TRUE,     # score validation error on every iteration, use with caution
    model_id = "loan_nn")            # for easy lookup in flow

# print model information
loan_nn

# view detailed results at http://ip:port/flow/index.html
# Out:
#   |======================================================================| 100%
# Model Details:
# ==============
#
# H2OBinomialModel: deeplearning
# Model ID:  loan_nn
# Status of Neuron Layers: predicting bad_loan, 2-class classification, bernoulli distribution, CrossEntropy loss, 9,102 weights/biases, 112.5 KB, 1,099,809 training samples, mini-batch size 1
#   layer units        type dropout       l1       l2 mean_rate rate_rms momentum
# 1     1    88       Input 20.00 %
# 2     2   100 TanhDropout  5.00 % 0.001000 0.010000  0.443643 0.211831 0.000000
# 3     3     2     Softmax         0.001000 0.010000  0.408911 0.100635 0.000000
#   mean_weight weight_rms mean_bias bias_rms
# 1
# 2   -0.001117   0.042712 -0.002015 0.021067
# 3    0.000013   0.050084 -0.003850 0.591340
#
#
# H2OBinomialMetrics: deeplearning
# ** Reported on training data. **
# ** Metrics reported on temporary training frame with 10059 samples **
#
# MSE:  0.1378801
# RMSE:  0.3713221
# LogLoss:  0.4383454
# Mean Per-Class Error:  0.3536357
# AUC:  0.6962695
# Gini:  0.3925391
#
# Confusion Matrix (vertical: actual; across: predicted) for F1-optimal threshold:
#           0    1    Error         Rate
# 0      5474 2762 0.335357   =2762/8236
# 1       678 1145 0.371914    =678/1823
# Totals 6152 3907 0.341982  =3440/10059
#
# Maximum Metrics: Maximum metrics at their respective thresholds
#                         metric threshold    value idx
# 1                       max f1  0.178902 0.399651 242
# 2                       max f2  0.108554 0.561702 328
# 3                 max f0point5  0.286644 0.359314 136
# 4                 max accuracy  0.488274 0.819167  21
# 5                max precision  0.488274 0.529412  21
# 6                   max recall  0.047216 1.000000 397
# 7              max specificity  0.588281 0.999879   0
# 8             max absolute_mcc  0.178902 0.231359 242
# 9   max min_per_class_accuracy  0.174014 0.645338 248
# 10 max mean_per_class_accuracy  0.175854 0.646449 246
#
# Gains/Lift Table: Extract with `h2o.gainsLift(<model>, <data>)` or `h2o.gainsLift(<model>, valid=<T/F>, xval=<T/F>)`
# H2OBinomialMetrics: deeplearning
# ** Reported on validation data. **
# ** Metrics reported on full validation frame **
#
# MSE:  0.1374883
# RMSE:  0.3707942
# LogLoss:  0.4374828
# Mean Per-Class Error:  0.3553472
# AUC:  0.6976978
# Gini:  0.3953955
#
# Confusion Matrix (vertical: actual; across: predicted) for F1-optimal threshold:
#            0     1    Error          Rate
# 0      27810 12624 0.312212  =12624/40434
# 1       3570  5389 0.398482    =3570/8959
# Totals 31380 18013 0.327860  =16194/49393
#
# Maximum Metrics: Maximum metrics at their respective thresholds
#                         metric threshold    value idx
# 1                       max f1  0.183690 0.399600 235
# 2                       max f2  0.108819 0.558869 327
# 3                 max f0point5  0.253536 0.361631 167
# 4                 max accuracy  0.462674 0.819144  34
# 5                max precision  0.616266 1.000000   0
# 6                   max recall  0.044620 1.000000 399
# 7              max specificity  0.616266 1.000000   0
# 8             max absolute_mcc  0.199868 0.232669 218
# 9   max min_per_class_accuracy  0.172317 0.644268 247
# 10 max mean_per_class_accuracy  0.174261 0.645387 245
#
# Gains/Lift Table: Extract with `h2o.gainsLift(<model>, <data>)` or `h2o.gainsLift(<model>, valid=<T/F>, xval=<T/F>)`

# %%
# NN with random hyperparameter search
# train many different NN models with random hyperparameters

# define random grid search parameters
hidden_opts = c(c(170, 320), c(80, 190), c(320, 160, 80), c(100), c(50, 50, 50, 50))
l1_opts = seq(0.001, 0.01, 0.001)
l2_opts = seq(0.001, 0.01, 0.001)
input_dropout_ratio_opts = seq(0.01, 0.5, 0.01)


hyper_params = list(hidden = hidden_opts,
                    l1 = l1_opts,
                    l2 = l2_opts,
                    input_dropout_ratio = input_dropout_ratio_opts)

# search a random subset of these hyper-parmameters
# max runtime and max models are enforced
# and the search will stop after not improving much over the best 5 random models
search_criteria = list(strategy = "RandomDiscrete", 
                       max_runtime_secs = 600, 
                       max_models = 20, 
                       stopping_metric = "AUC", 
                       stopping_tolerance = 0.0001, 
                       stopping_rounds = 5, 
                       seed = 123456)

# execute training w/ grid search
loan_nn2 <- h2o.grid("deeplearning", 
                     grid_id = "nn_grid",
                     x = X, 
                     y = y, 
                     training_frame = train,
                     validation_frame = valid,
                     
                     # per model stopping criteria 
                     stopping_rounds = 2,
                     stopping_tolerance = 1e-3,
                     stopping_metric = "AUC",
                     
                     # how often to score (affects early stopping, and training speed)
                     score_interval = 5, 
                     
                     # seed to control sampling
                     seed = 12345,
                     
                     # grid serach options
                     hyper_params = hyper_params,
                     search_criteria = search_criteria)

# view detailed results at http://ip:port/flow/index.html
# Out:
#   |======================================================================| 100%

# %%
# show grid results
sorted_grid <- h2o.getGrid(grid_id = "nn_grid")
print(sorted_grid)
# Out:
# H2O Grid Details
# ================
#
# Grid ID: nn_grid
# Used hyper parameters:
#   -  hidden
#   -  input_dropout_ratio
#   -  l1
#   -  l2
# Number of models: 20
# Number of failed models: 0
#
# Hyper-Parameter Search Summary: ordered by increasing logloss
#    hidden input_dropout_ratio    l1    l2        model_ids             logloss
# 1   [190]                0.08 0.006 0.002  nn_grid_model_9 0.43616330923467383
# 2   [160]                0.01 0.005 0.004  nn_grid_model_6  0.4362472262834775
# 3   [100]                0.01 0.006 0.008  nn_grid_model_5 0.43658843292209554
# 4   [190]                0.26 0.001 0.005  nn_grid_model_0 0.43659485855062946
# 5   [100]                0.05 0.009 0.004  nn_grid_model_4  0.4368972977466567
# 6    [50]                0.34 0.006 0.009  nn_grid_model_3 0.43704377579091835
# 7    [50]                0.08 0.002 0.006 nn_grid_model_11  0.4371954303289583
# 8   [160]                0.08 0.002 0.007  nn_grid_model_1 0.43747381819811965
# 9    [80]                0.29 0.008 0.001 nn_grid_model_14   0.437540052252791
# 10   [50]                0.42 0.003 0.005 nn_grid_model_10 0.43765005285705716
# 11  [190]                0.24 0.007 0.004  nn_grid_model_7  0.4378248225316097
# 12  [160]                0.35 0.003 0.005 nn_grid_model_16 0.43788671063069196
# 13   [80]                0.26 0.002 0.006  nn_grid_model_2  0.4384206870688338
# 14   [50]                 0.3  0.01  0.01 nn_grid_model_12  0.4400531675722677
# 15   [80]                0.38 0.002 0.006 nn_grid_model_18 0.44078841123051743
# 16   [50]                0.18 0.007 0.009 nn_grid_model_19  0.4419241955132811
# 17  [320]                0.45 0.005 0.008 nn_grid_model_13 0.44337632178846637
# 18   [50]                0.48 0.005 0.003 nn_grid_model_17  0.4454402419411345
# 19  [320]                0.03 0.004 0.001 nn_grid_model_15 0.44582633842730995
# 20  [320]                0.42 0.005 0.003  nn_grid_model_8 0.45673338792380774

# %%
# select best model
best_model <- h2o.getModel(sorted_grid@model_ids[[1]])
summary(best_model)
# Out:
# Model Details:
# ==============
#
# H2OBinomialModel: deeplearning
# Model Key:  nn_grid_model_9
# Status of Neuron Layers: predicting bad_loan, 2-class classification, bernoulli distribution, CrossEntropy loss, 17,292 weights/biases, 209.6 KB, 1,200,379 training samples, mini-batch size 1
#   layer units      type dropout       l1       l2 mean_rate rate_rms momentum
# 1     1    88     Input  8.00 %
# 2     2   190 Rectifier  0.00 % 0.006000 0.002000  0.142957 0.247649 0.000000
# 3     3     2   Softmax         0.006000 0.002000  0.117802 0.011875 0.000000
#   mean_weight weight_rms mean_bias bias_rms
# 1
# 2   -0.022819   0.050838  0.002004 0.036277
# 3    0.000040   0.053681 -0.000099 0.062499
#
# H2OBinomialMetrics: deeplearning
# ** Reported on training data. **
# ** Metrics reported on temporary training frame with 9928 samples **
#
# MSE:  0.1389205
# RMSE:  0.3727205
# LogLoss:  0.4402771
# Mean Per-Class Error:  0.352888
# AUC:  0.6976046
# Gini:  0.3952092
#
# Confusion Matrix (vertical: actual; across: predicted) for F1-optimal threshold:
#           0    1    Error        Rate
# 0      5538 2573 0.317224  =2573/8111
# 1       706 1111 0.388553   =706/1817
# Totals 6244 3684 0.330278  =3279/9928
#
# Maximum Metrics: Maximum metrics at their respective thresholds
#                         metric threshold    value idx
# 1                       max f1  0.195803 0.403927 195
# 2                       max f2  0.114538 0.566850 291
# 3                 max f0point5  0.274874 0.356268 122
# 4                 max accuracy  0.467896 0.813961   0
# 5                max precision  0.467896 0.453988   0
# 6                   max recall  0.009040 1.000000 397
# 7              max specificity  0.467896 0.978054   0
# 8             max absolute_mcc  0.195803 0.235506 195
# 9   max min_per_class_accuracy  0.185113 0.647221 208
# 10 max mean_per_class_accuracy  0.179987 0.649725 213
#
# Gains/Lift Table: Extract with `h2o.gainsLift(<model>, <data>)` or `h2o.gainsLift(<model>, valid=<T/F>, xval=<T/F>)`
# H2OBinomialMetrics: deeplearning
# ** Reported on validation data. **
# ** Metrics reported on full validation frame **
#
# MSE:  0.1372154
# RMSE:  0.370426
# LogLoss:  0.4361633
# Mean Per-Class Error:  0.3564202
# AUC:  0.6997233
# Gini:  0.3994465
#
# Confusion Matrix (vertical: actual; across: predicted) for F1-optimal threshold:
#            0     1    Error          Rate
# 0      28838 11596 0.286788  =11596/40434
# 1       3817  5142 0.426052    =3817/8959
# Totals 32655 16738 0.312048  =15413/49393
#
# Maximum Metrics: Maximum metrics at their respective thresholds
#                         metric threshold    value idx
# 1                       max f1  0.204320 0.400202 191
# 2                       max f2  0.114531 0.562812 295
# 3                 max f0point5  0.292411 0.363195 113
# 4                 max accuracy  0.467897 0.816229   0
# 5                max precision  0.467897 0.463217   0
# 6                   max recall  0.000428 1.000000 399
# 7              max specificity  0.467897 0.978706   0
# 8             max absolute_mcc  0.212541 0.234196 183
# 9   max min_per_class_accuracy  0.181677 0.643048 214
# 10 max mean_per_class_accuracy  0.189246 0.645395 207
#
# Gains/Lift Table: Extract with `h2o.gainsLift(<model>, <data>)` or `h2o.gainsLift(<model>, valid=<T/F>, xval=<T/F>)`
#
#
# Scoring History:
#             timestamp          duration training_speed   epochs iterations
# 1 2017-04-09 15:45:48         0.000 sec                 0.00000          0
# 2 2017-04-09 15:45:49  1 min 23.045 sec  86856 obs/sec  0.87316          1
# 3 2017-04-09 15:45:55  1 min 28.358 sec 114173 obs/sec  6.10748          7
# 4 2017-04-09 15:45:59  1 min 32.675 sec 118579 obs/sec 10.47506         12
#          samples training_rmse training_logloss training_auc training_lift
# 1       0.000000
# 2  100059.000000       0.37385          0.44348      0.69384       2.89589
# 3  699881.000000       0.37232          0.43998      0.69613       2.95053
# 4 1200379.000000       0.37272          0.44028      0.69760       2.40414
#   training_classification_error validation_rmse validation_logloss
# 1
# 2                       0.37339         0.37179            0.43962
# 3                       0.35284         0.37066            0.43706
# 4                       0.33028         0.37043            0.43616
#   validation_auc validation_lift validation_classification_error
# 1
# 2        0.69553         2.49992                         0.33873
# 3        0.69684         2.80125                         0.32468
# 4        0.69972         2.48876                         0.31205

# %%
# use partial dependence plots to get insight into important relationships
h2o.partialPlot(best_model, valid, "int_rate")
# Out:
#   |======================================================================| 100%
#    int_rate  mean_response stddev_response
# 1   5.420000 0.08416702    0.03698123
# 2   6.506316 0.09277872    0.04024507
# 3   7.592632 0.10215785    0.04370043
# 4   8.678947 0.11234989    0.04733855
# 5   9.765263 0.12339890    0.05114917
# 6  10.851579 0.13534581    0.05511484
# 7  11.937895 0.14822497    0.05919854
# 8  13.024211 0.16206575    0.06336391
# 9  14.110526 0.17689040    0.06757106
# 10 15.196842 0.19271233    0.07177496
# 11 16.283158 0.20953079    0.07591296
# 12 17.369474 0.22731336    0.07986225
# 13 18.455789 0.24597905    0.08342562
# 14 19.542105 0.26538480    0.08634336
# 15 20.628421 0.28537166    0.08844190
# 16 21.714737 0.30573831    0.08957022
# 17 22.801053 0.32623282    0.08959957
# 18 23.887368 0.34650754    0.08837498
# 19 24.973684 0.36613462    0.08577743
# 20 26.060000 0.38464348    0.08178843
# plot without title
