# %%
# import h2o lib and allow it to use max. threads
library(h2o)
h2o.init(nthreads = -1)
# Out:
# H2O is not running yet, starting it now...
#
# Note:  In case of errors look at the following log files:
#     /var/folders/tc/0ss1l73113j3wdyjsxmy1j2r0000gn/T//RtmpjNm2kZ/h2o_phall_started_from_r.out
#     /var/folders/tc/0ss1l73113j3wdyjsxmy1j2r0000gn/T//RtmpjNm2kZ/h2o_phall_started_from_r.err
#
#
# Starting H2O JVM and connecting: .. Connection successful!
#
# R is connected to the H2O cluster:
#     H2O cluster uptime:         1 seconds 931 milliseconds
#     H2O cluster version:        3.12.0.1
#     H2O cluster version age:    29 days
#     H2O cluster name:           H2O_started_from_R_phall_pzf065
#     H2O cluster total nodes:    1
#     H2O cluster total memory:   3.56 GB
#     H2O cluster total cores:    8
#     H2O cluster allowed cores:  8
#     H2O cluster healthy:        TRUE
#     H2O Connection ip:          localhost
#     H2O Connection port:        54321
#     H2O Connection proxy:       NA
#     H2O Internal Security:      FALSE
#     R Version:                  R version 3.3.2 (2016-10-31)

# %%
# location of clean data file
path <- "/Users/phall/Documents/aetna/share/data/loan.csv"

# %%
# import file
frame <- h2o.importFile(path)

# strings automatically parsed as enums (categorical)
# numbers automatically parsed as numeric
# bad_loan is numeric, but categorical
frame$bad_loan <- as.factor(frame$bad_loan)
# Out:
#   |======================================================================| 100%

# %%
# summarize table
# decision tree ensembles can run on missing values
h2o.describe(frame)
# Out:
#    Label                 Type Missing Zeros  PosInf NegInf Min     Max
# 1  loan_amnt             int     0         0 0      0       500.00   35000.00
# 2  term                  enum    0    129950 0      0         0.00       1.00
# 3  int_rate              real    0         0 0      0         5.42      26.06
# 4  emp_length            int  5804     14248 0      0         0.00      10.00
# 5  home_ownership        enum    0         1 0      0         0.00       5.00
# 6  annual_inc            real    4         0 0      0      1896.00 7141778.00
# 7  purpose               enum    0      2842 0      0         0.00      13.00
# 8  addr_state            enum    0       413 0      0         0.00      49.00
# 9  dti                   real    0       270 0      0         0.00      39.99
# 10 delinq_2yrs           int    29    139459 0      0         0.00      29.00
# 11 revol_util            real  193      1562 0      0         0.00     150.70
# 12 total_acc             int    29         0 0      0         1.00     118.00
# 13 bad_loan              enum    0    133971 0      0         0.00       1.00
# 14 longest_credit_length int    29        11 0      0         0.00      65.00
# 15 verification_status   enum    0     59155 0      0         0.00       1.00
#    Mean         Sigma        Cardinality
# 1  1.307417e+04 7.993556e+03 NA
# 2  2.075591e-01 4.055605e-01  2
# 3  1.371590e+01 4.391940e+00 NA
# 4  5.684353e+00 3.610664e+00 NA
# 5            NA           NA  6
# 6  7.191567e+04 5.907092e+04 NA
# 7            NA           NA 14
# 8            NA           NA 50
# 9  1.588153e+01 7.587668e+00 NA
# 10 2.273570e-01 6.941679e-01 NA
# 11 5.407917e+01 2.528537e+01 NA
# 12 2.457973e+01 1.168519e+01 NA
# 13 1.830389e-01 3.866996e-01  2
# 14 1.485427e+01 6.947733e+00 NA
# 15 6.392702e-01 4.802137e-01  2

# %%
# assign target and inputs
y <- 'bad_loan'
X <- names(frame)[names(frame) != y]
print(y)
print(X)
# Out:
# [1] "bad_loan"
#  [1] "loan_amnt"             "term"                  "int_rate"
#  [4] "emp_length"            "home_ownership"        "annual_inc"
#  [7] "purpose"               "addr_state"            "dti"
# [10] "delinq_2yrs"           "revol_util"            "total_acc"
# [13] "longest_credit_length" "verification_status"

# %%
# split into training and valid
split <- h2o.splitFrame(frame, ratios = 0.7)
train <- split[[1]]
valid <- split[[2]]

# %%
# random forest
# random forest is often the best guess model with little tuning

# train
loan_rf <- h2o.randomForest(
    x = X,
    y = y,
    training_frame = train,
    validation_frame = valid,
    ntrees = 500,                      # Up to 500 decision trees in the forest 
    max_depth = 30,                    # trees can grow to depth of 30
    stopping_rounds = 2,               # stop after validation error does not decrease for 5 iterations/new trees
    score_each_iteration = TRUE,       # score validation error on every iteration/new tree
    model_id = "loan_rf")              # for easy lookup in flow

# print model information
loan_rf

# view detailed results at http://ip:port/flow/index.html
# Out:
#   |======================================================================| 100%
# Model Details:
# ==============
#
# H2OBinomialModel: drf
# Model ID:  loan_rf
# Model Summary:
#   number_of_trees number_of_internal_trees model_size_in_bytes min_depth
# 1              76                       76            15536744        30
#   max_depth mean_depth min_leaves max_leaves mean_leaves
# 1        30   30.00000      14307      15595 15031.52600
#
#
# H2OBinomialMetrics: drf
# ** Reported on training data. **
# ** Metrics reported on Out-Of-Bag training samples **
#
# MSE:  0.1424317
# RMSE:  0.3774012
# LogLoss:  0.5384553
# Mean Per-Class Error:  0.3747821
# AUC:  0.6711422
# Gini:  0.3422843
#
# Confusion Matrix (vertical: actual; across: predicted) for F1-optimal threshold:
#            0     1    Error           Rate
# 0      60494 33346 0.355350   =33346/93840
# 1       8245 12670 0.394215    =8245/20915
# Totals 68739 46016 0.362433  =41591/114755
#
# Maximum Metrics: Maximum metrics at their respective thresholds
#                         metric threshold    value idx
# 1                       max f1  0.204672 0.378599 249
# 2                       max f2  0.078676 0.546351 345
# 3                 max f0point5  0.314294 0.336944 174
# 4                 max accuracy  0.708713 0.817977  15
# 5                max precision  0.888889 1.000000   0
# 6                   max recall  0.000001 1.000000 399
# 7              max specificity  0.888889 1.000000   0
# 8             max absolute_mcc  0.234359 0.200572 227
# 9   max min_per_class_accuracy  0.196034 0.623966 255
# 10 max mean_per_class_accuracy  0.204672 0.625218 249
#
# Gains/Lift Table: Extract with `h2o.gainsLift(<model>, <data>)` or `h2o.gainsLift(<model>, valid=<T/F>, xval=<T/F>)`
# H2OBinomialMetrics: drf
# ** Reported on validation data. **
#
# MSE:  0.1402196
# RMSE:  0.3744591
# LogLoss:  0.4520236
# Mean Per-Class Error:  0.3611967
# AUC:  0.689377
# Gini:  0.3787539
#
# Confusion Matrix (vertical: actual; across: predicted) for F1-optimal threshold:
#            0     1    Error          Rate
# 0      27253 12878 0.320899  =12878/40131
# 1       3654  5447 0.401494    =3654/9101
# Totals 30907 18325 0.335798  =16532/49232
#
# Maximum Metrics: Maximum metrics at their respective thresholds
#                         metric threshold    value idx
# 1                       max f1  0.212594 0.397214 224
# 2                       max f2  0.101935 0.559347 327
# 3                 max f0point5  0.304298 0.361362 152
# 4                 max accuracy  0.539455 0.816197  39
# 5                max precision  0.702632 0.700000   7
# 6                   max recall  0.000002 1.000000 399
# 7              max specificity  0.793860 0.999975   0
# 8             max absolute_mcc  0.251128 0.224451 192
# 9   max min_per_class_accuracy  0.198471 0.634985 238
# 10 max mean_per_class_accuracy  0.212594 0.638803 224
#
# Gains/Lift Table: Extract with `h2o.gainsLift(<model>, <data>)` or `h2o.gainsLift(<model>, valid=<T/F>, xval=<T/F>)`

# %%
# GBM with random hyperparameter search
# GBM often more accurate than random forest but requires some tuning

# define random grid search parameters
ntrees_opts = seq(100, 500, 50)
max_depth_opts = seq(2, 20, 2)
sample_rate_opts = seq(0.1, 0.9, 0.1)
col_sample_rate_opts = seq(0.1, 0.9, 0.1)

hyper_params = list(ntrees = ntrees_opts,
                    max_depth = max_depth_opts,
                    sample_rate = sample_rate_opts,
                    col_sample_rate = col_sample_rate_opts)

# search a random subset of these hyper-parmameters
# max runtime and max models are enforced
# and the search will stop after not improving much over the best 5 random models
search_criteria = list(strategy = "RandomDiscrete", 
                       max_runtime_secs = 600, 
                       max_models = 20, 
                       stopping_metric = "AUC", 
                       stopping_tolerance = 0.0001, 
                       stopping_rounds = 5, 
                       seed = 12345)

# execute training w/ grid search
loan_gbm <- h2o.grid("gbm", 
                     grid_id = "gbm_grid",
                     x = X, 
                     y = y, 
                     training_frame = train,
                     validation_frame = valid,
                     
                     # per model stopping criteria 
                     stopping_rounds = 2,
                     stopping_tolerance = 1e-3,
                     stopping_metric = "AUC",
                     
                     # how often to score (affects early stopping, training speed)
                     score_tree_interval = 5, 
                     
                     # seed to control sampling 
                     seed = 12345,
                     # grid serach options
                     hyper_params = hyper_params,
                     search_criteria = search_criteria)

# view detailed results at http://ip:port/flow/index.html
# Out:
#   |======================================================================| 100%

# %%
# show grid results
sorted_grid <- h2o.getGrid(grid_id = "gbm_grid")
print(sorted_grid)
# Out:
# H2O Grid Details
# ================
#
# Grid ID: gbm_grid
# Used hyper parameters:
#   -  col_sample_rate
#   -  max_depth
#   -  ntrees
#   -  sample_rate
# Number of models: 20
# Number of failed models: 0
#
# Hyper-Parameter Search Summary: ordered by increasing logloss
#    col_sample_rate max_depth ntrees sample_rate         model_ids
# 1              0.3         4    350         0.4  gbm_grid_model_9
# 2              0.6         6    100         0.6 gbm_grid_model_16
# 3              0.3         4    150         0.1 gbm_grid_model_17
# 4              0.4         2    250         0.7  gbm_grid_model_0
# 5              0.1         2    350         0.6 gbm_grid_model_13
# 6              0.4        10    400         0.6  gbm_grid_model_1
# 7              0.8        10    400         0.6  gbm_grid_model_5
# 8              0.1        10    500         0.1  gbm_grid_model_7
# 9              0.2        14    250         0.8  gbm_grid_model_4
# 10             0.5        12    250         0.7 gbm_grid_model_19
# 11             0.9        12    450         0.6 gbm_grid_model_10
# 12             0.2        14    350         0.2 gbm_grid_model_11
# 13             0.9        14    400         0.6  gbm_grid_model_8
# 14             0.9        14    150         0.8  gbm_grid_model_2
# 15             0.6        14    300         0.7 gbm_grid_model_15
# 16             0.3        20    500         0.6 gbm_grid_model_14
# 17             0.5        16    150         0.1  gbm_grid_model_3
# 18             0.5        16    500         0.1 gbm_grid_model_12
# 19             0.7        16    400         0.1 gbm_grid_model_18
# 20             0.8        20    200         0.7  gbm_grid_model_6
#                logloss
# 1   0.4379848127345179
# 2   0.4381495805976454
# 3   0.4404367234352526
# 4    0.440658756868947
# 5   0.4427578018029036
# 6   0.4436340796364082
# 7  0.44423238962712736
# 8  0.44499117836415414
# 9   0.4465847872389083
# 10  0.4474806073276194
# 11 0.45056756551236243
# 12 0.45459018590436023
# 13  0.4572277747384341
# 14 0.45770538201158756
# 15 0.45858456100806777
# 16  0.4674671894406781
# 17 0.46822526407928733
# 18 0.46822526407928733
# 19 0.46836430689590536
# 20  0.5065872254107707

# %%
# select best model
best_model <- h2o.getModel(sorted_grid@model_ids[[1]])
summary(best_model)
# Out:
# Model Details:
# ==============
#
# H2OBinomialModel: gbm
# Model Key:  gbm_grid_model_9
# Model Summary:
#   number_of_trees number_of_internal_trees model_size_in_bytes min_depth
# 1              70                       70               48112         4
#   max_depth mean_depth min_leaves max_leaves mean_leaves
# 1         4    4.00000          9         16    15.00000
#
# H2OBinomialMetrics: gbm
# ** Reported on training data. **
#
# MSE:  0.1348012
# RMSE:  0.3671529
# LogLoss:  0.4281231
# Mean Per-Class Error:  0.34324
# AUC:  0.7193566
# Gini:  0.4387132
#
# Confusion Matrix (vertical: actual; across: predicted) for F1-optimal threshold:
#            0     1    Error           Rate
# 0      67199 26641 0.283898   =26641/93840
# 1       8420 12495 0.402582    =8420/20915
# Totals 75619 39136 0.305529  =35061/114755
#
# Maximum Metrics: Maximum metrics at their respective thresholds
#                         metric threshold    value idx
# 1                       max f1  0.206819 0.416146 220
# 2                       max f2  0.114905 0.571406 309
# 3                 max f0point5  0.307836 0.386525 140
# 4                 max accuracy  0.483086 0.820025  45
# 5                max precision  0.676910 0.900000   3
# 6                   max recall  0.026669 1.000000 396
# 7              max specificity  0.725030 0.999989   0
# 8             max absolute_mcc  0.239895 0.257256 191
# 9   max min_per_class_accuracy  0.187275 0.658140 238
# 10 max mean_per_class_accuracy  0.179828 0.659612 245
#
# Gains/Lift Table: Extract with `h2o.gainsLift(<model>, <data>)` or `h2o.gainsLift(<model>, valid=<T/F>, xval=<T/F>)`
# H2OBinomialMetrics: gbm
# ** Reported on validation data. **
#
# MSE:  0.1382457
# RMSE:  0.371814
# LogLoss:  0.4379848
# Mean Per-Class Error:  0.3522123
# AUC:  0.7040679
# Gini:  0.4081358
#
# Confusion Matrix (vertical: actual; across: predicted) for F1-optimal threshold:
#            0     1    Error          Rate
# 0      27370 12761 0.317984  =12761/40131
# 1       3517  5584 0.386441    =3517/9101
# Totals 30887 18345 0.330639  =16278/49232
#
# Maximum Metrics: Maximum metrics at their respective thresholds
#                         metric threshold    value idx
# 1                       max f1  0.195925 0.406908 226
# 2                       max f2  0.118019 0.568177 305
# 3                 max f0point5  0.282814 0.372759 155
# 4                 max accuracy  0.488864 0.816034  42
# 5                max precision  0.725903 1.000000   0
# 6                   max recall  0.025375 1.000000 397
# 7              max specificity  0.725903 1.000000   0
# 8             max absolute_mcc  0.237698 0.241007 188
# 9   max min_per_class_accuracy  0.185064 0.646852 237
# 10 max mean_per_class_accuracy  0.190872 0.648092 231
#
# Gains/Lift Table: Extract with `h2o.gainsLift(<model>, <data>)` or `h2o.gainsLift(<model>, valid=<T/F>, xval=<T/F>)`
#
#
# Scoring History:
#              timestamp          duration number_of_trees training_rmse
# 1  2017-07-06 15:50:09  1 min 54.046 sec               0       0.38606
# 2  2017-07-06 15:50:09  1 min 54.161 sec               5       0.37847
# 3  2017-07-06 15:50:09  1 min 54.502 sec              10       0.37455
# 4  2017-07-06 15:50:10  1 min 54.970 sec              15       0.37234
# 5  2017-07-06 15:50:10  1 min 55.562 sec              20       0.37102
# 6  2017-07-06 15:50:11  1 min 56.186 sec              25       0.37010
# 7  2017-07-06 15:50:11  1 min 56.854 sec              30       0.36945
# 8  2017-07-06 15:50:12  1 min 57.546 sec              35       0.36901
# 9  2017-07-06 15:50:13  1 min 58.285 sec              40       0.36864
# 10 2017-07-06 15:50:14  1 min 59.144 sec              45       0.36830
# 11 2017-07-06 15:50:15  2 min  0.195 sec              50       0.36798
# 12 2017-07-06 15:50:16  2 min  1.179 sec              55       0.36776
# 13 2017-07-06 15:50:17  2 min  2.184 sec              60       0.36752
# 14 2017-07-06 15:50:18  2 min  3.285 sec              65       0.36731
# 15 2017-07-06 15:50:19  2 min  4.440 sec              70       0.36715
#    training_logloss training_auc training_lift training_classification_error
# 1           0.47480      0.50000       1.00000                       0.81774
# 2           0.45604      0.69369       2.79495                       0.34192
# 3           0.44660      0.69833       2.81984                       0.33570
# 4           0.44131      0.70272       2.88675                       0.31063
# 5           0.43809      0.70601       3.05881                       0.32099
# 6           0.43557      0.70867       3.09226                       0.31294
# 7           0.43378      0.71011       3.11616                       0.31221
# 8           0.43266      0.71154       3.19741                       0.31330
# 9           0.43164      0.71319       3.18307                       0.29885
# 10          0.43081      0.71450       3.19263                       0.29107
# 11          0.43007      0.71588       3.18785                       0.30808
# 12          0.42956      0.71674       3.24520                       0.29806
# 13          0.42898      0.71763       3.23086                       0.31672
# 14          0.42850      0.71861       3.27388                       0.31237
# 15          0.42812      0.71936       3.24042                       0.30553
#    validation_rmse validation_logloss validation_auc validation_lift
# 1          0.38819            0.47871        0.50000         1.00000
# 2          0.38085            0.46050        0.68700         2.67191
# 3          0.37708            0.45142        0.69220         2.77608
# 4          0.37513            0.44673        0.69535         2.86386
# 5          0.37404            0.44404        0.69777         2.84192
# 6          0.37333            0.44204        0.69933         2.96261
# 7          0.37282            0.44063        0.70041         2.96261
# 8          0.37258            0.43991        0.70116         2.85289
# 9          0.37239            0.43943        0.70166         2.89678
# 10         0.37221            0.43898        0.70223         2.85289
# 11         0.37209            0.43866        0.70285         2.85289
# 12         0.37200            0.43845        0.70316         2.86386
# 13         0.37191            0.43822        0.70353         2.85289
# 14         0.37184            0.43802        0.70403         2.92970
# 15         0.37181            0.43798        0.70407         2.90775
#    validation_classification_error
# 1                          0.81514
# 2                          0.33622
# 3                          0.35981
# 4                          0.31350
# 5                          0.31486
# 6                          0.30714
# 7                          0.31705
# 8                          0.31069
# 9                          0.31636
# 10                         0.30159
# 11                         0.32936
# 12                         0.30230
# 13                         0.31311
# 14                         0.29800
# 15                         0.33064
#
# Variable Importances: (Extract with `h2o.varimp`)
# =================================================
#
# Variable Importances:
#                 variable relative_importance scaled_importance percentage
# 1               int_rate         2620.247559          1.000000   0.451130
# 2                   term          645.164246          0.246223   0.111078
# 3             addr_state          598.834900          0.228541   0.103102
# 4             annual_inc          558.047546          0.212975   0.096079
# 5                    dti          341.925201          0.130493   0.058870
# 6             revol_util          334.958801          0.127835   0.057670
# 7                purpose          257.972839          0.098454   0.044415
# 8              loan_amnt          168.724228          0.064392   0.029049
# 9             emp_length           74.849014          0.028566   0.012887
# 10             total_acc           68.440407          0.026120   0.011783
# 11   verification_status           49.041447          0.018716   0.008444
# 12        home_ownership           44.676147          0.017050   0.007692
# 13 longest_credit_length           36.959839          0.014105   0.006363
# 14           delinq_2yrs            8.346249          0.003185   0.001437

# %%
# use variable importance to get insight into important relationships
h2o.varimp(best_model)
# Out:
#    variable              relative_importance scaled_importance percentage
# 1  int_rate              2620.247559         1.00000000        0.451129917
# 2  term                   645.164246         0.24622263        0.111078395
# 3  addr_state             598.834900         0.22854134        0.103101838
# 4  annual_inc             558.047546         0.21297512        0.096079450
# 5  dti                    341.925201         0.13049347        0.058869509
# 6  revol_util             334.958801         0.12783479        0.057670099
# 7  purpose                257.972839         0.09845361        0.044415370
# 8  loan_amnt              168.724228         0.06439248        0.029049372
# 9  emp_length              74.849014         0.02856563        0.012886809
# 10 total_acc               68.440407         0.02611982        0.011783434
# 11 verification_status     49.041447         0.01871634        0.008443501
# 12 home_ownership          44.676147         0.01705035        0.007691925
# 13 longest_credit_length   36.959839         0.01410548        0.006363402
# 14 delinq_2yrs              8.346249         0.00318529        0.001436980

# %%
# use partial dependence plots to get insight into important relationships
h2o.partialPlot(best_model, valid, "int_rate")
# Out:
#   |======================================================================| 100%
#    int_rate  mean_response stddev_response
# 1   5.420000 0.07635569    0.04293206
# 2   6.506316 0.07635569    0.04293206
# 3   7.592632 0.09022306    0.04889183
# 4   8.678947 0.10956080    0.05369815
# 5   9.765263 0.12255792    0.05438731
# 6  10.851579 0.13442127    0.05985479
# 7  11.937895 0.14375390    0.06150664
# 8  13.024211 0.16183460    0.06246395
# 9  14.110526 0.18350078    0.06645215
# 10 15.196842 0.19332465    0.06996814
# 11 16.283158 0.22301115    0.07874675
# 12 17.369474 0.24300457    0.07970754
# 13 18.455789 0.25936730    0.08646305
# 14 19.542105 0.26101509    0.08718693
# 15 20.628421 0.26628467    0.08994791
# 16 21.714737 0.29244030    0.09549504
# 17 22.801053 0.29517321    0.09743704
# 18 23.887368 0.29450394    0.09701679
# 19 24.973684 0.29855674    0.09806179
# 20 26.060000 0.29933002    0.09645770
# plot without title

# %%
h2o.shutdown(prompt = FALSE)
# Out:
# [1] TRUE
