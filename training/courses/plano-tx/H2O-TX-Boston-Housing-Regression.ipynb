# %%
import h2o

# %%
h2o.init(strict_version_check=False)
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321. connected.
# --------------------------  ----------------------------------------
# H2O cluster uptime:         1 day 1 hour 6 mins
# H2O cluster version:        3.14.0.6
# H2O cluster version age:    23 days
# H2O cluster name:           H2O_started_from_R_avkashchauhan_hwc594
# H2O cluster total nodes:    1
# H2O cluster free memory:    3.308 Gb
# H2O cluster total cores:    8
# H2O cluster allowed cores:  8
# H2O cluster status:         locked, healthy
# H2O connection url:         http://localhost:54321
# H2O connection proxy:
# H2O internal security:      False
# H2O API Extensions:         XGBoost, Algos, AutoML, Core V3, Core V4
# Python version:             2.7.13 final
# --------------------------  ----------------------------------------

# %%
df_train = h2o.import_file("https://raw.githubusercontent.com/h2oai/h2o-tutorials/master/training/plano-tx/house_price_train.csv")
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%

# %%
df_test = h2o.import_file("https://raw.githubusercontent.com/h2oai/h2o-tutorials/master/training/plano-tx/house_price_test.csv")
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%

# %%
print(df_train.shape)
print(df_test.shape)
# Out:
# (407, 14)
# (99, 14)

# %%
import pylab as pl
df_train.as_data_frame().hist(figsize=(20,10))
pl.show()

# %%
import pylab as pl
df_test.as_data_frame().hist(figsize=(20,10))
pl.show()

# %%
df_train.col_names
# Out:
# [u'crim',
#  u'zn',
#  u'indus',
#  u'chas',
#  u'nox',
#  u'rm',
#  u'age',
#  u'dis',
#  u'rad',
#  u'tax',
#  u'ptratio',
#  u'b',
#  u'lstat',
#  u'medv']

# %%
response = "medv"

# %%
features= df_train.col_names

# %%
features.remove(response)
print(features)
# Out:
# [u'crim', u'zn', u'indus', u'chas', u'nox', u'rm', u'age', u'dis', u'rad', u'tax', u'ptratio', u'b', u'lstat']

# %%
from h2o.estimators.glm import H2OGeneralizedLinearEstimator

# %%
h2o_glm = H2OGeneralizedLinearEstimator(nfolds = 5)

# %%
h2o_glm.train(x = features, y = response, training_frame= df_frain)
# Out:
# glm Model Build progress: |███████████████████████████████████████████████| 100%

# %%
h2o_glm
# Out:
# Model Details
# =============
# H2OGeneralizedLinearEstimator :  Generalized Linear Modeling
# Model Key:  GLM_model_python_1509561268558_89
#
#
# ModelMetricsRegressionGLM: glm
# ** Reported on train data. **
#
# MSE: 21.4904862593
# RMSE: 4.63578324119
# MAE: 3.17657880157
# RMSLE: NaN
# R^2: 0.744639059652
# Mean Residual Deviance: 21.4904862593
# Null degrees of freedom: 406
# Residual degrees of freedom: 393
# Null deviance: 34252.0194968
# Residual deviance: 8746.62790752
# AIC: 2433.53337345
#
# ModelMetricsRegressionGLM: glm
# ** Reported on cross-validation data. **
#
# MSE: 25.2027105951
# RMSE: 5.02023013368
# MAE: 3.38988113704
# RMSLE: NaN
# R^2: 0.700528512979
# Mean Residual Deviance: 25.2027105951
# Null degrees of freedom: 406
# Residual degrees of freedom: 393
# Null deviance: 34378.5416033
# Residual deviance: 10257.5032122
# AIC: 2498.3852477
# Cross-Validation Metrics Summary:
#                         mean      sd         cv_1_valid    cv_2_valid    cv_3_valid    cv_4_valid    cv_5_valid
# ----------------------  --------  ---------  ------------  ------------  ------------  ------------  ------------
# mae                     3.38727   0.172656   3.37332       3.01783       3.2435        3.6208        3.6809
# mean_residual_deviance  25.2118   5.98647    21.0667       16.9913       19.9659       27.2712       40.7637
# mse                     25.2118   5.98647    21.0667       16.9913       19.9659       27.2712       40.7637
# null_deviance           6875.71   1079.47    6483.5        7015.77       4372.74       9095.57       7410.96
# r2                      0.690128  0.0681106  0.733253      0.812277      0.602584      0.748541      0.553987
# residual_deviance       2051.5    478.639    1727.47       1308.33       1697.1        2263.51       3261.09
# rmse                    4.95741   0.563846   4.58985       4.12205       4.46833       5.22218       6.38464
# rmsle                   0.260881  0.0446375  0.352364      0.207499      nan           0.239545      0.244114
# Scoring History:
#     timestamp            duration    iterations    negative_log_likelihood    objective
# --  -------------------  ----------  ------------  -------------------------  -----------
#     2017-11-02 12:46:05  0.000 sec   0             34252                      84.1573

# %%
h2o_glm_pred= h2o_glm.predict(df_test)
# Out:
# glm prediction progress: |████████████████████████████████████████████████| 100%

# %%
h2o_glm_pred
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  predict</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">  30.1893</td></tr>
# <tr><td style="text-align: right;">  25.7295</td></tr>
# <tr><td style="text-align: right;">  16.194 </td></tr>
# <tr><td style="text-align: right;">  14.0706</td></tr>
# <tr><td style="text-align: right;">  11.6645</td></tr>
# <tr><td style="text-align: right;">  14.4757</td></tr>
# <tr><td style="text-align: right;">  22.9229</td></tr>
# <tr><td style="text-align: right;">  22.6934</td></tr>
# <tr><td style="text-align: right;">  30.3847</td></tr>
# <tr><td style="text-align: right;">  21.0683</td></tr>
# </tbody>
# </table>

# %%
h2o_glm.model_performance(df_train)
# Out:
# ModelMetricsRegressionGLM: glm
# ** Reported on test data. **
#
# MSE: 21.4904862593
# RMSE: 4.63578324119
# MAE: 3.17657880157
# RMSLE: NaN
# R^2: 0.744639059652
# Mean Residual Deviance: 21.4904862593
# Null degrees of freedom: 406
# Residual degrees of freedom: 393
# Null deviance: 34252.0194968
# Residual deviance: 8746.62790752
# AIC: 2433.53337345

# %%
h2o_glm.model_performance(df_test)
# Out:
# ModelMetricsRegressionGLM: glm
# ** Reported on test data. **
#
# MSE: 24.9481243387
# RMSE: 4.99480973999
# MAE: 3.78642958789
# RMSLE: 0.259648815062
# R^2: 0.707592977773
# Mean Residual Deviance: 24.9481243387
# Null degrees of freedom: 98
# Residual degrees of freedom: 85
# Null deviance: 8468.5597644
# Residual deviance: 2469.86430954
# AIC: 629.412895189

# %%
h2o_glm.model_performance(df_train)
# Out:
# ModelMetricsRegressionGLM: glm
# ** Reported on test data. **
#
# MSE: 21.4904862593
# RMSE: 4.63578324119
# MAE: 3.17657880157
# RMSLE: NaN
# R^2: 0.744639059652
# Mean Residual Deviance: 21.4904862593
# Null degrees of freedom: 406
# Residual degrees of freedom: 393
# Null deviance: 34252.0194968
# Residual deviance: 8746.62790752
# AIC: 2433.53337345

# %%
h2o_glm.model_performance(train=True)
# Out:
# ModelMetricsRegressionGLM: glm
# ** Reported on train data. **
#
# MSE: 21.4904862593
# RMSE: 4.63578324119
# MAE: 3.17657880157
# RMSLE: NaN
# R^2: 0.744639059652
# Mean Residual Deviance: 21.4904862593
# Null degrees of freedom: 406
# Residual degrees of freedom: 393
# Null deviance: 34252.0194968
# Residual deviance: 8746.62790752
# AIC: 2433.53337345

# %%
h2o_glm.model_performance(valid==True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-5027da225041> in <module>()
# ----> 1 h2o_glm.model_performance(valid==True)
#
# NameError: name 'valid' is not defined

# %%
h2o_glm.model_performance(xval=True)
# Out:
# ModelMetricsRegressionGLM: glm
# ** Reported on cross-validation data. **
#
# MSE: 25.2027105951
# RMSE: 5.02023013368
# MAE: 3.38988113704
# RMSLE: NaN
# R^2: 0.700528512979
# Mean Residual Deviance: 25.2027105951
# Null degrees of freedom: 406
# Residual degrees of freedom: 393
# Null deviance: 34378.5416033
# Residual deviance: 10257.5032122
# AIC: 2498.3852477

# %%
h2o_glm.model_performance(test_data=df_test)
# Out:
# ModelMetricsRegressionGLM: glm
# ** Reported on test data. **
#
# MSE: 24.9481243387
# RMSE: 4.99480973999
# MAE: 3.78642958789
# RMSLE: 0.259648815062
# R^2: 0.707592977773
# Mean Residual Deviance: 24.9481243387
# Null degrees of freedom: 98
# Residual degrees of freedom: 85
# Null deviance: 8468.5597644
# Residual deviance: 2469.86430954
# AIC: 629.412895189

# %%
df_train.col_names
# Out:
# [u'crim',
#  u'zn',
#  u'indus',
#  u'chas',
#  u'nox',
#  u'rm',
#  u'age',
#  u'dis',
#  u'rad',
#  u'tax',
#  u'ptratio',
#  u'b',
#  u'lstat',
#  u'medv']

# %%
print(h2o_glm.r2(train=True))
print(h2o_glm.r2(valid=True))
print(h2o_glm.r2(xval=True))
# Out:
# 0.744639059652
# None
# 0.700528512979

# %%
h2o_glm.varimp()
# Out:
# Warning: This model doesn't have variable importances

# %%
h2o_glm.varimp_plot()
# Out:
# Variable importance does not apply to GLM. Will use std_coef_plot() instead.

# %%
# partial dependence plots are a powerful machine learning interpretation tool
# to calculate partial dependence across the domain a variable
# hold column of interest at constant value
# find the mean prediction of the model with this column constant
# repeat for multiple values of the variable of interest
# h2o has a built-in function for partial dependence as well

glm_pdp_rm = h2o_glm.partial_plot(data=df_train, cols=['rm'], server=True, plot=True)
# Out:
# PartialDependencePlot progress: |█████████████████████████████████████████| 100%

# %%
glm_pdp_rm
# Out:
# PartialDependence: Partial Dependence Plot of model GLM_model_python_1509561268558_89 on column 'rm'
# rm       mean_response    stddev_response
# -------  ---------------  -----------------
# 3.863    12.4446          5.70505
# 4.11889  13.5195          5.70505
# 4.37479  14.5944          5.70505
# 4.63068  15.6693          5.70505
# 4.88658  16.7442          5.70505
# 5.14247  17.819           5.70505
# 5.39837  18.8939          5.70505
# 5.65426  19.9688          5.70505
# 5.91016  21.0437          5.70505
# 6.16605  22.1185          5.70505
# 6.42195  23.1934          5.70505
# 6.67784  24.2683          5.70505
# 6.93374  25.3432          5.70505
# 7.18963  26.418           5.70505
# 7.44553  27.4929          5.70505
# 7.70142  28.5678          5.70505
# 7.95732  29.6427          5.70505
# 8.21321  30.7175          5.70505
# 8.46911  31.7924          5.70505
# 8.725    32.8673          5.70505
# []

# %%
from h2o.estimators.gbm import H2OGradientBoostingEstimator

# %%
h2o_gbm = H2OGradientBoostingEstimator(nfolds=5)

# %%
h2o_gbm.train(x=features, y= response, training_frame=df_train)
# Out:
# gbm Model Build progress: |███████████████████████████████████████████████| 100%

# %%
h2o_gbm.varimp()
# Out:
# [(u'lstat', 105866.8125, 1.0, 0.6047348824410893),
#  (u'rm', 39758.8984375, 0.37555582810713223, 0.22711170956043256),
#  (u'dis', 11466.9921875, 0.108315268181896, 0.06550202097055394),
#  (u'nox', 6184.43994140625, 0.05841717338383311, 0.035326902478813045),
#  (u'crim', 3648.995849609375, 0.03446779744699856, 0.02084387943711395),
#  (u'ptratio', 2454.009033203125, 0.023180154150793244, 0.014017847795346278),
#  (u'tax', 2219.060546875, 0.020960870498249864, 0.012675769556622028),
#  (u'age', 1424.7196044921875, 0.013457660345560962, 0.008138316647004916),
#  (u'b', 1419.9967041015625, 0.013413048627506023, 0.008111338384931468),
#  (u'indus', 331.3314514160156, 0.0031297008343952513, 0.0018926392661637913),
#  (u'rad', 159.52056884765625, 0.0015068043051514018, 0.0009112171243374602),
#  (u'zn', 107.55658721923828, 0.0010159613261166078, 0.00061438725311382),
#  (u'chas', 20.848114013671875, 0.0001969277578246901, 0.00011908908447750126)]

# %%
h2o_gbm.varimp_plot()

# %%
gbm_pdp_rm = h2o_gbm.partial_plot(data=df_train, cols=['crim'], server=True, plot=True)
# Out:
# PartialDependencePlot progress: |█████████████████████████████████████████| 100%

# %%
gbm_pdp_rm
# Out:
# PartialDependence: Partial Dependence Plot of model GBM_model_python_1509561268558_90 on column 'crim'
# crim     mean_response    stddev_response
# -------  ---------------  -----------------
# 0.00906  22.8993          8.29657
# 3.8788   23.4597          8.76411
# 7.74854  23.2172          9.02842
# 11.6183  23.1067          9.29128
# 15.488   23.1991          9.22406
# 19.3578  22.2977          9.49207
# 23.2275  22.2605          9.52834
# 27.0972  22.2605          9.52834
# 30.967   22.2605          9.52834
# 34.8367  22.2605          9.52834
# 38.7064  22.2605          9.52834
# 42.5762  22.2605          9.52834
# 46.4459  22.2605          9.52834
# 50.3157  22.2605          9.52834
# 54.1854  22.2605          9.52834
# 58.0551  22.2605          9.52834
# 61.9249  22.2605          9.52834
# 65.7946  22.2605          9.52834
# 69.6644  22.2605          9.52834
# 73.5341  22.2605          9.52834
# []

# %%
## Can we build a logistic regression/Classfication model? 
df_train[response] = df_train[response].asfactor()
df_test[response] = df_test[response].asfactor()
# Out:
# ---------------------------------------------------------------------------
# H2OValueError                             Traceback (most recent call last)
# <ipython-input-83-daf974e42b21> in <module>()
# ----> 1 df_train[response] = df_train[response].asfactor()
#       2 df_test[response] = df_test[response].asfactor()
#
# /Users/avkashchauhan/anaconda3/envs/python27/lib/python2.7/site-packages/h2o/frame.pyc in asfactor(self)
#    2218             if t not in {"bool", "int", "string", "enum"}:
#    2219                 raise H2OValueError("Only 'int' or 'string' are allowed for "
# -> 2220                                     "asfactor(), got %s:%s " % (colname, t))
#    2221         fr = H2OFrame._expr(expr=ExprNode("as.factor", self), cache=self._ex._cache)
#    2222         if fr._ex._cache.types_valid():
#
# H2OValueError: Only 'int' or 'string' are allowed for asfactor(), got medv:real
