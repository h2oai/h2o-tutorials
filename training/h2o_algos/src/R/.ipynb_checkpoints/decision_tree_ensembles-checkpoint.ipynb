# %%
# import h2o lib and allow it to use max. threads
library(h2o)
h2o.init(nthreads = -1)
# Out:
# ----------------------------------------------------------------------
#
# Your next step is to start H2O:
#     > h2o.init()
#
# For H2O package documentation, ask for help:
#     > ??h2o
#
# After starting H2O, you can use the Web UI at http://localhost:54321
# For more information visit http://docs.h2o.ai
#
# ----------------------------------------------------------------------
#
#
# Attaching package: ‘h2o’
#
# The following objects are masked from ‘package:stats’:
#
#     cor, sd, var
#
# The following objects are masked from ‘package:base’:
#
#     &&, %*%, %in%, ||, apply, as.factor, as.numeric, colnames,
#     colnames<-, ifelse, is.character, is.factor, is.numeric, log,
#     log10, log1p, log2, round, signif, trunc
# H2O is not running yet, starting it now...
#
# Note:  In case of errors look at the following log files:
#     /var/folders/tc/0ss1l73113j3wdyjsxmy1j2r0000gn/T//RtmpQ3T24j/h2o_phall_started_from_r.out
#     /var/folders/tc/0ss1l73113j3wdyjsxmy1j2r0000gn/T//RtmpQ3T24j/h2o_phall_started_from_r.err
#
#
# Starting H2O JVM and connecting: .. Connection successful!
#
# R is connected to the H2O cluster:
#     H2O cluster uptime:         2 seconds 706 milliseconds
#     H2O cluster version:        3.10.4.3
#     H2O cluster version age:    8 days
#     H2O cluster name:           H2O_started_from_R_phall_muv691
#     H2O cluster total nodes:    1
#     H2O cluster total memory:   3.56 GB
#     H2O cluster total cores:    8
#     H2O cluster allowed cores:  8
#     H2O cluster healthy:        TRUE
#     H2O Connection ip:          localhost
#     H2O Connection port:        54321
#     H2O Connection proxy:       NA
#     H2O Internal Security:      FALSE
#     R Version:                  R version 3.3.2 (2016-10-31)

# %%
# location of clean data file
path <- "https://raw.githubusercontent.com/h2oai/app-consumer-loan/master/data/loan.csv"

# %%
# import file
frame <- h2o.importFile(path)

# strings automatically parsed as enums (categorical)
# numbers automatically parsed as numeric
# bad_loan is numeric, but categorical
frame$bad_loan <- as.factor(frame$bad_loan)
# Out:
#   |======================================================================| 100%

# %%
# summarize table
# decision tree ensembles can run on missing values
h2o.describe(frame)
# Out:
#    Label                 Type Missing Zeros  PosInf NegInf Min  Max
# 1  loan_amnt             int  0       0      0      0      500  35000
# 2  term                  enum 0       129950 0      0      0    1
# 3  int_rate              real 0       0      0      0      5.42 26.06
# 4  emp_length            int  5804    14248  0      0      0    10
# 5  home_ownership        enum 0       1      0      0      0    5
# 6  annual_inc            real 4       0      0      0      1896 7141778
# 7  purpose               enum 0       2842   0      0      0    13
# 8  addr_state            enum 0       413    0      0      0    49
# 9  dti                   real 0       270    0      0      0    39.99
# 10 delinq_2yrs           int  29      139459 0      0      0    29
# 11 revol_util            real 193     1562   0      0      0    150.7
# 12 total_acc             int  29      0      0      0      1    118
# 13 bad_loan              enum 0       133971 0      0      0    1
# 14 longest_credit_length int  29      11     0      0      0    65
# 15 verification_status   enum 0       59155  0      0      0    1
#    Mean              Sigma             Cardinality
# 1  13074.1691414563  7993.55618873467  NA
# 2  0.207559135785154 0.405560530549521 2
# 3  13.7159040655662  4.39193987054581  NA
# 4  5.68435293299534  3.61066373110024  NA
# 5  NA                NA                6
# 6  71915.6705197491  59070.9156549182  NA
# 7  NA                NA                14
# 8  NA                NA                50
# 9  15.8815301212902  7.58766822419254  NA
# 10 0.227357006062527 0.694167922928419 NA
# 11 54.0791728024226  25.2853667667705  NA
# 12 24.5797338342746  11.6851903659107  NA
# 13 0.183038899424954 0.386699589607887 2
# 14 14.8542736554483  6.94773292254669  NA
# 15 0.639270186051333 0.480213724833117 2

# %%
# assign target and inputs
y <- 'bad_loan'
X <- names(frame)[names(frame) != y]
print(y)
print(X)
# Out:
# [1] "bad_loan"
#  [1] "loan_amnt"             "term"                  "int_rate"
#  [4] "emp_length"            "home_ownership"        "annual_inc"
#  [7] "purpose"               "addr_state"            "dti"
# [10] "delinq_2yrs"           "revol_util"            "total_acc"
# [13] "longest_credit_length" "verification_status"

# %%
# split into training and valid
split <- h2o.splitFrame(frame, ratios = 0.7)
train <- split[[1]]
valid <- split[[2]]

# %%
# random forest
# random forest is often the best guess model with little tuning

# train
loan_rf <- h2o.randomForest(
    x = X,
    y = y,
    training_frame = train,
    validation_frame = valid,
    ntrees = 500,                      # Up to 500 decision trees in the forest 
    max_depth = 30,                    # trees can grow to depth of 30
    stopping_rounds = 5,               # stop after validation error does not decrease for 5 iterations/new trees
    score_each_iteration = TRUE,       # score validation error on every iteration/new tree
    model_id = "loan_rf")              # for easy lookup in flow

# print model information
loan_rf

# view detailed results at http://ip:port/flow/index.html
# Out:
#   |======================================================================| 100%
# Model Details:
# ==============
#
# H2OBinomialModel: drf
# Model ID:  loan_rf
# Model Summary:
#   number_of_trees number_of_internal_trees model_size_in_bytes min_depth
# 1             101                      101            20695527        30
#   max_depth mean_depth min_leaves max_leaves mean_leaves
# 1        30   30.00000      14311      15780 15057.37600
#
#
# H2OBinomialMetrics: drf
# ** Reported on training data. **
# ** Metrics reported on Out-Of-Bag training samples **
#
# MSE:  0.1416737
# RMSE:  0.3763957
# LogLoss:  0.4964933
# Mean Per-Class Error:  0.3692102
# AUC:  0.6793498
# Gini:  0.3586995
#
# Confusion Matrix (vertical: actual; across: predicted) for F1-optimal threshold:
#            0     1    Error           Rate
# 0      62575 31107 0.332049   =31107/93682
# 1       8572 12522 0.406371    =8572/21094
# Totals 71147 43629 0.345708  =39679/114776
#
# Maximum Metrics: Maximum metrics at their respective thresholds
#                         metric threshold    value idx
# 1                       max f1  0.213108 0.386941 237
# 2                       max f2  0.087046 0.552281 336
# 3                 max f0point5  0.318318 0.348469 164
# 4                 max accuracy  0.640271 0.816556  26
# 5                max precision  0.714286 0.563380  12
# 6                   max recall  0.000004 1.000000 399
# 7              max specificity  0.864865 0.999989   0
# 8             max absolute_mcc  0.244116 0.210492 213
# 9   max min_per_class_accuracy  0.199998 0.627442 248
# 10 max mean_per_class_accuracy  0.208228 0.630856 241
#
# Gains/Lift Table: Extract with `h2o.gainsLift(<model>, <data>)` or `h2o.gainsLift(<model>, valid=<T/F>, xval=<T/F>)`
# H2OBinomialMetrics: drf
# ** Reported on validation data. **
#
# MSE:  0.1390898
# RMSE:  0.3729474
# LogLoss:  0.4459391
# Mean Per-Class Error:  0.3657808
# AUC:  0.6862452
# Gini:  0.3724905
#
# Confusion Matrix (vertical: actual; across: predicted) for F1-optimal threshold:
#            0     1    Error          Rate
# 0      27329 12960 0.321676  =12960/40289
# 1       3657  5265 0.409886    =3657/8922
# Totals 30986 18225 0.337668  =16617/49211
#
# Maximum Metrics: Maximum metrics at their respective thresholds
#                         metric threshold    value idx
# 1                       max f1  0.214797 0.387888 219
# 2                       max f2  0.108911 0.556265 319
# 3                 max f0point5  0.316835 0.346097 145
# 4                 max accuracy  0.537594 0.819105  39
# 5                max precision  0.758447 1.000000   0
# 6                   max recall  0.000030 1.000000 399
# 7              max specificity  0.758447 1.000000   0
# 8             max absolute_mcc  0.216042 0.214207 218
# 9   max min_per_class_accuracy  0.199030 0.629455 234
# 10 max mean_per_class_accuracy  0.179838 0.634773 251
#
# Gains/Lift Table: Extract with `h2o.gainsLift(<model>, <data>)` or `h2o.gainsLift(<model>, valid=<T/F>, xval=<T/F>)`

# %%
# GBM with random hyperparameter search
# GBM often more accurate than random forest but requires some tuning

# define random grid search parameters
ntrees_opts = seq(100, 500, 50)
max_depth_opts = seq(2, 20, 2)
sample_rate_opts = seq(0.1, 0.9, 0.1)
col_sample_rate_opts = seq(0.1, 0.9, 0.1)

hyper_params = list(ntrees = ntrees_opts,
                    max_depth = max_depth_opts,
                    sample_rate = sample_rate_opts,
                    col_sample_rate = col_sample_rate_opts)

# search a random subset of these hyper-parmameters
# max runtime and max models are enforced
# and the search will stop after not improving much over the best 5 random models
search_criteria = list(strategy = "RandomDiscrete", 
                       max_runtime_secs = 600, 
                       max_models = 20, 
                       stopping_metric = "AUC", 
                       stopping_tolerance = 0.0001, 
                       stopping_rounds = 5, 
                       seed = 12345)

# execute training w/ grid search
loan_gbm <- h2o.grid("gbm", 
                     grid_id = "gbm_grid",
                     x = X, 
                     y = y, 
                     training_frame = train,
                     validation_frame = valid,
                     
                     # per model stopping criteria 
                     stopping_rounds = 2,
                     stopping_tolerance = 1e-3,
                     stopping_metric = "AUC",
                     
                     # how often to score (affects early stopping, training speed)
                     score_tree_interval = 5, 
                     
                     # seed to control sampling 
                     seed = 12345,
                     
                     # grid serach options
                     hyper_params = hyper_params,
                     search_criteria = search_criteria)

# view detailed results at http://ip:port/flow/index.html
# Out:
#   |======================================================================| 100%

# %%
# show grid results
sorted_grid <- h2o.getGrid(grid_id = "gbm_grid")
print(sorted_grid)
# Out:
# H2O Grid Details
# ================
#
# Grid ID: gbm_grid
# Used hyper parameters:
#   -  col_sample_rate
#   -  max_depth
#   -  ntrees
#   -  sample_rate
# Number of models: 20
# Number of failed models: 0
#
# Hyper-Parameter Search Summary: ordered by increasing logloss
#    col_sample_rate max_depth ntrees sample_rate         model_ids
# 1              0.8         6    200         0.8 gbm_grid_model_15
# 2              0.1         8    150         0.9  gbm_grid_model_7
# 3              0.6         4    150         0.4 gbm_grid_model_10
# 4              0.8         4    100         0.3  gbm_grid_model_8
# 5              0.8         2    100         0.4  gbm_grid_model_5
# 6              0.3         2    400         0.2  gbm_grid_model_6
# 7              0.9         8    100         0.7  gbm_grid_model_3
# 8              0.1        12    500         0.3  gbm_grid_model_0
# 9              0.1        16    450         0.2 gbm_grid_model_11
# 10             0.2        10    250         0.2 gbm_grid_model_13
# 11             0.5        10    200         0.3  gbm_grid_model_4
# 12             0.9        12    400         0.4  gbm_grid_model_2
# 13             0.6        10    250         0.1 gbm_grid_model_16
# 14             0.3        16    250         0.9  gbm_grid_model_1
# 15             0.7        16    150         0.6 gbm_grid_model_17
# 16             0.3        16    150         0.2 gbm_grid_model_19
# 17             0.6        16    200         0.2 gbm_grid_model_18
# 18             0.7        16    200         0.4  gbm_grid_model_9
# 19             0.9        20    300         0.3 gbm_grid_model_12
# 20             0.4        18    300         0.9 gbm_grid_model_14
#                logloss
# 1  0.43514868073259566
# 2   0.4357608183327341
# 3   0.4358491560638527
# 4    0.436418430478159
# 5    0.436570543487778
# 6  0.43683611077961226
# 7  0.43854191795372643
# 8  0.43921026582643763
# 9   0.4421448696029961
# 10 0.44317503785805945
# 11 0.44345571767287323
# 12 0.44975687403364584
# 13 0.45030597177425535
# 14  0.4519787341045961
# 15  0.4550368987115437
# 16 0.45706465664175683
# 17 0.45890309920037115
# 18  0.4591997345343429
# 19  0.4669297768837732
# 20 0.46846501672078394

# %%
# select best model
best_model <- h2o.getModel(sorted_grid@model_ids[[1]])
summary(best_model)
# Out:
# Model Details:
# ==============
#
# H2OBinomialModel: gbm
# Model Key:  gbm_grid_model_15
# Model Summary:
#   number_of_trees number_of_internal_trees model_size_in_bytes min_depth
# 1              55                       55               73198         6
#   max_depth mean_depth min_leaves max_leaves mean_leaves
# 1         6    6.00000         30         64    56.27273
#
# H2OBinomialMetrics: gbm
# ** Reported on training data. **
#
# MSE:  0.1295168
# RMSE:  0.3598844
# LogLoss:  0.412861
# Mean Per-Class Error:  0.3227909
# AUC:  0.7546572
# Gini:  0.5093144
#
# Confusion Matrix (vertical: actual; across: predicted) for F1-optimal threshold:
#            0     1    Error           Rate
# 0      73937 19745 0.210766   =19745/93682
# 1       9172 11922 0.434816    =9172/21094
# Totals 83109 31667 0.251943  =28917/114776
#
# Maximum Metrics: Maximum metrics at their respective thresholds
#                         metric threshold    value idx
# 1                       max f1  0.232478 0.451925 206
# 2                       max f2  0.126688 0.591408 302
# 3                 max f0point5  0.334278 0.449787 136
# 4                 max accuracy  0.438031 0.826898  81
# 5                max precision  0.846286 1.000000   0
# 6                   max recall  0.024410 1.000000 395
# 7              max specificity  0.846286 1.000000   0
# 8             max absolute_mcc  0.244537 0.308972 196
# 9   max min_per_class_accuracy  0.191105 0.682564 242
# 10 max mean_per_class_accuracy  0.196658 0.683259 237
#
# Gains/Lift Table: Extract with `h2o.gainsLift(<model>, <data>)` or `h2o.gainsLift(<model>, valid=<T/F>, xval=<T/F>)`
# H2OBinomialMetrics: gbm
# ** Reported on validation data. **
#
# MSE:  0.1370647
# RMSE:  0.3702224
# LogLoss:  0.4351487
# Mean Per-Class Error:  0.3540747
# AUC:  0.7004081
# Gini:  0.4008162
#
# Confusion Matrix (vertical: actual; across: predicted) for F1-optimal threshold:
#            0     1    Error          Rate
# 0      28200 12089 0.300057  =12089/40289
# 1       3641  5281 0.408092    =3641/8922
# Totals 31841 17370 0.319644  =15730/49211
#
# Maximum Metrics: Maximum metrics at their respective thresholds
#                         metric threshold    value idx
# 1                       max f1  0.201306 0.401719 228
# 2                       max f2  0.115744 0.562049 310
# 3                 max f0point5  0.293739 0.361472 157
# 4                 max accuracy  0.625719 0.819085  19
# 5                max precision  0.815537 1.000000   0
# 6                   max recall  0.025513 1.000000 395
# 7              max specificity  0.815537 1.000000   0
# 8             max absolute_mcc  0.201306 0.235284 228
# 9   max min_per_class_accuracy  0.182992 0.646156 245
# 10 max mean_per_class_accuracy  0.185256 0.647890 243
#
# Gains/Lift Table: Extract with `h2o.gainsLift(<model>, <data>)` or `h2o.gainsLift(<model>, valid=<T/F>, xval=<T/F>)`
#
#
# Scoring History:
#              timestamp          duration number_of_trees training_rmse
# 1  2017-04-09 16:01:13  3 min  2.953 sec               0       0.38731
# 2  2017-04-09 16:01:14  3 min  3.145 sec               5       0.37628
# 3  2017-04-09 16:01:14  3 min  3.640 sec              10       0.37117
# 4  2017-04-09 16:01:15  3 min  4.232 sec              15       0.36830
# 5  2017-04-09 16:01:15  3 min  4.927 sec              20       0.36642
# 6  2017-04-09 16:01:16  3 min  5.707 sec              25       0.36493
# 7  2017-04-09 16:01:17  3 min  6.599 sec              30       0.36374
# 8  2017-04-09 16:01:18  3 min  7.583 sec              35       0.36287
# 9  2017-04-09 16:01:19  3 min  8.652 sec              40       0.36199
# 10 2017-04-09 16:01:20  3 min  9.821 sec              45       0.36118
# 11 2017-04-09 16:01:22  3 min 11.091 sec              50       0.36053
# 12 2017-04-09 16:01:23  3 min 12.444 sec              55       0.35988
#    training_logloss training_auc training_lift training_classification_error
# 1           0.47708      0.50000       1.00000                       0.81622
# 2           0.45044      0.71398       3.51685                       0.29573
# 3           0.43844      0.72108       3.60691                       0.29502
# 4           0.43184      0.72592       3.76806                       0.28348
# 5           0.42752      0.73109       3.85337                       0.28918
# 6           0.42422      0.73562       3.98608                       0.26190
# 7           0.42148      0.74027       4.02400                       0.26372
# 8           0.41942      0.74353       4.08562                       0.26714
# 9           0.41744      0.74677       4.11879                       0.26350
# 10          0.41564      0.74977       4.17093                       0.25105
# 11          0.41426      0.75236       4.19937                       0.26722
# 12          0.41286      0.75466       4.30838                       0.25194
#    validation_rmse validation_logloss validation_auc validation_lift
# 1          0.38528            0.47338        0.50000         1.00000
# 2          0.37647            0.45172        0.68890         2.57399
# 3          0.37306            0.44318        0.69211         2.70750
# 4          0.37170            0.43955        0.69374         2.70750
# 5          0.37112            0.43785        0.69536         2.62918
# 6          0.37086            0.43701        0.69639         2.65156
# 7          0.37059            0.43627        0.69790         2.65156
# 8          0.37046            0.43584        0.69876         2.67394
# 9          0.37033            0.43552        0.69945         2.70750
# 10         0.37027            0.43531        0.69992         2.74106
# 11         0.37026            0.43527        0.70010         2.69631
# 12         0.37022            0.43515        0.70041         2.71869
#    validation_classification_error
# 1                          0.81870
# 2                          0.31853
# 3                          0.32040
# 4                          0.32911
# 5                          0.34923
# 6                          0.33527
# 7                          0.34720
# 8                          0.33127
# 9                          0.32702
# 10                         0.32993
# 11                         0.33210
# 12                         0.31964
#
# Variable Importances: (Extract with `h2o.varimp`)
# =================================================
#
# Variable Importances:
#                 variable relative_importance scaled_importance percentage
# 1               int_rate         4211.119141          1.000000   0.377249
# 2             addr_state         2225.969238          0.528593   0.199411
# 3             annual_inc          969.671448          0.230265   0.086867
# 4                   term          873.531494          0.207435   0.078254
# 5                purpose          748.537048          0.177753   0.067057
# 6                    dti          624.533875          0.148306   0.055948
# 7              loan_amnt          441.840637          0.104922   0.039582
# 8             revol_util          316.847473          0.075241   0.028384
# 9             emp_length          212.580017          0.050481   0.019044
# 10             total_acc          207.565521          0.049290   0.018595
# 11 longest_credit_length          144.595184          0.034337   0.012953
# 12        home_ownership          137.783524          0.032719   0.012343
# 13           delinq_2yrs           31.822008          0.007557   0.002851
# 14   verification_status           16.309155          0.003873   0.001461

# %%
# use variable importance to get insight into important relationships
h2o.varimp(best_model)
# Out:
#    variable              relative_importance scaled_importance percentage
# 1  int_rate              4211.11914          1.000000000       0.377248960
# 2  addr_state            2225.96924          0.528593270       0.199411262
# 3  annual_inc             969.67145          0.230264549       0.086867061
# 4  term                   873.53149          0.207434524       0.078254458
# 5  purpose                748.53705          0.177752522       0.067056954
# 6  dti                    624.53387          0.148305914       0.055948252
# 7  loan_amnt              441.84064          0.104922379       0.039581858
# 8  revol_util             316.84747          0.075240681       0.028384469
# 9  emp_length             212.58002          0.050480647       0.019043771
# 10 total_acc              207.56552          0.049289871       0.018594553
# 11 longest_credit_length  144.59518          0.034336522       0.012953417
# 12 home_ownership         137.78352          0.032718980       0.012343201
# 13 delinq_2yrs             31.82201          0.007556663       0.002850743
# 14 verification_status     16.30915          0.003872879       0.001461040

# %%
# use partial dependence plots to get insight into important relationships
h2o.partialPlot(best_model, valid, "int_rate")
# Out:
#   |======================================================================| 100%
#    int_rate  mean_response stddev_response
# 1   5.420000 0.07228458    0.04613215
# 2   6.506316 0.07063097    0.04456902
# 3   7.592632 0.08499076    0.04677204
# 4   8.678947 0.09960179    0.04977327
# 5   9.765263 0.11920764    0.05741436
# 6  10.851579 0.13128068    0.06283089
# 7  11.937895 0.14568999    0.06980484
# 8  13.024211 0.16275976    0.07370855
# 9  14.110526 0.19021279    0.07672524
# 10 15.196842 0.20304354    0.07862770
# 11 16.283158 0.22514940    0.08361148
# 12 17.369474 0.23608464    0.08861335
# 13 18.455789 0.26508752    0.09480751
# 14 19.542105 0.26435083    0.09478931
# 15 20.628421 0.26837936    0.09431707
# 16 21.714737 0.31397467    0.10160242
# 17 22.801053 0.32118946    0.10324264
# 18 23.887368 0.31974777    0.10331658
# 19 24.973684 0.32986869    0.10141793
# 20 26.060000 0.32574129    0.10091202
# plot without title
