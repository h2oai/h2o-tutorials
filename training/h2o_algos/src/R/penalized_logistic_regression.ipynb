# %%
# import h2o lib and allow it to use max. threads
library(h2o)
h2o.init(nthreads = -1)
# Out:
# ----------------------------------------------------------------------
#
# Your next step is to start H2O:
#     > h2o.init()
#
# For H2O package documentation, ask for help:
#     > ??h2o
#
# After starting H2O, you can use the Web UI at http://localhost:54321
# For more information visit http://docs.h2o.ai
#
# ----------------------------------------------------------------------
#
#
# Attaching package: ‘h2o’
#
# The following objects are masked from ‘package:stats’:
#
#     cor, sd, var
#
# The following objects are masked from ‘package:base’:
#
#     &&, %*%, %in%, ||, apply, as.factor, as.numeric, colnames,
#     colnames<-, ifelse, is.character, is.factor, is.numeric, log,
#     log10, log1p, log2, round, signif, trunc
# H2O is not running yet, starting it now...
#
# Note:  In case of errors look at the following log files:
#     /var/folders/tc/0ss1l73113j3wdyjsxmy1j2r0000gn/T//RtmpT1fNJA/h2o_phall_started_from_r.out
#     /var/folders/tc/0ss1l73113j3wdyjsxmy1j2r0000gn/T//RtmpT1fNJA/h2o_phall_started_from_r.err
#
#
# Starting H2O JVM and connecting: .. Connection successful!
#
# R is connected to the H2O cluster:
#     H2O cluster uptime:         1 seconds 651 milliseconds
#     H2O cluster version:        3.12.0.1
#     H2O cluster version age:    29 days
#     H2O cluster name:           H2O_started_from_R_phall_mng351
#     H2O cluster total nodes:    1
#     H2O cluster total memory:   3.56 GB
#     H2O cluster total cores:    8
#     H2O cluster allowed cores:  8
#     H2O cluster healthy:        TRUE
#     H2O Connection ip:          localhost
#     H2O Connection port:        54321
#     H2O Connection proxy:       NA
#     H2O Internal Security:      FALSE
#     R Version:                  R version 3.3.2 (2016-10-31)

# %%
# location of clean data file
path <- "/Users/phall/Documents/aetna/share/data/loan.csv"

# %%
# import file
frame <- h2o.importFile(path)

# strings automatically parsed as enums (categorical)
# numbers automatically parsed as numeric
# bad_loan is numeric, but categorical
frame$bad_loan <- as.factor(frame$bad_loan)
# Out:
#   |======================================================================| 100%

# %%
# find missing numeric and impute
for (name in names(frame)) {
  if (any(is.na(frame[name]))) {
      h2o.impute(frame, name, "median")
  }
}

# %%
h2o.describe(frame) # summarize table, check for missing
# Out:
#    Label                 Type Missing Zeros  PosInf NegInf Min     Max
# 1  loan_amnt             int  0            0 0      0       500.00   35000.00
# 2  term                  enum 0       129950 0      0         0.00       1.00
# 3  int_rate              real 0            0 0      0         5.42      26.06
# 4  emp_length            int  0        14248 0      0         0.00      10.00
# 5  home_ownership        enum 0            1 0      0         0.00       5.00
# 6  annual_inc            real 0            0 0      0      1896.00 7141778.00
# 7  purpose               enum 0         2842 0      0         0.00      13.00
# 8  addr_state            enum 0          413 0      0         0.00      49.00
# 9  dti                   real 0          270 0      0         0.00      39.99
# 10 delinq_2yrs           int  0       139488 0      0         0.00      29.00
# 11 revol_util            real 0         1562 0      0         0.00     150.70
# 12 total_acc             int  0            0 0      0         1.00     118.00
# 13 bad_loan              enum 0       133971 0      0         0.00       1.00
# 14 longest_credit_length int  0           11 0      0         0.00      65.00
# 15 verification_status   enum 0        59155 0      0         0.00       1.00
#    Mean         Sigma        Cardinality
# 1  1.307417e+04 7.993556e+03 NA
# 2  2.075591e-01 4.055605e-01  2
# 3  1.371590e+01 4.391940e+00 NA
# 4  5.695525e+00 3.546671e+00 NA
# 5            NA           NA  6
# 6  7.191540e+04 5.907022e+04 NA
# 7            NA           NA 14
# 8            NA           NA 50
# 9  1.588153e+01 7.587668e+00 NA
# 10 2.273168e-01 6.941131e-01 NA
# 11 5.408120e+01 2.527055e+01 NA
# 12 2.457945e+01 1.168418e+01 NA
# 13 1.830389e-01 3.866996e-01  2
# 14 1.485412e+01 6.947128e+00 NA
# 15 6.392702e-01 4.802137e-01  2

# %%
# assign target and inputs
y <- 'bad_loan'
X <- names(frame)[names(frame) != y]
print(y)
print(X)
# Out:
# [1] "bad_loan"
#  [1] "loan_amnt"             "term"                  "int_rate"
#  [4] "emp_length"            "home_ownership"        "annual_inc"
#  [7] "purpose"               "addr_state"            "dti"
# [10] "delinq_2yrs"           "revol_util"            "total_acc"
# [13] "longest_credit_length" "verification_status"

# %%
# split into training and test for cross validation
split <- h2o.splitFrame(frame, ratios = 0.7)
train <- split[[1]]
test <- split[[2]]

# %%
# elastic net regularized regression
#   - binomial family for logistic regression
#   - L1 for variable selection
#   - L2 for handling multicollinearity
#   - IRLS for handling outliers
#   - standardization very important for penalized regression variable selection
#   - with lamba parameter tuning for variable selection and regularization

# train
loan_glm <- h2o.glm(x = X, 
                    y = y,
                    training_frame = train,
                    validation_frame = test,
                    family = "binomial",
                    model_id = "loan_glm",
                    solver = "IRLSM",
                    standardize = TRUE, 
                    lambda_search = TRUE)

# print model
loan_glm

# view detailed results at http://ip:port/flow/index.html
# Out:
#   |======================================================================| 100%
# Model Details:
# ==============
#
# H2OBinomialModel: glm
# Model ID:  loan_glm
# GLM Model: summary
#     family  link                                regularization
# 1 binomial logit Elastic Net (alpha = 0.5, lambda = 1.257E-4 )
#                                                                  lambda_search
# 1 nlambda = 100, lambda.max = 0.1782, lambda.min = 1.257E-4, lambda.1se = -1.0
#   number_of_predictors_total number_of_active_predictors number_of_iterations
# 1                         83                          55                   91
#    training_frame
# 1 RTMP_sid_8698_3
#
# Coefficients: glm coefficients
#           names coefficients standardized_coefficients
# 1     Intercept    -2.891055                 -1.399306
# 2 addr_state.AK    -0.142204                 -0.142204
# 3 addr_state.AL     0.108174                  0.108174
# 4 addr_state.AR     0.000000                  0.000000
# 5 addr_state.AZ    -0.023154                 -0.023154
#
# ---
#                    names coefficients standardized_coefficients
# 79            annual_inc    -0.000006                 -0.385131
# 80                   dti     0.022454                  0.170378
# 81           delinq_2yrs     0.036031                  0.024920
# 82            revol_util     0.004212                  0.106415
# 83             total_acc    -0.009485                 -0.110783
# 84 longest_credit_length     0.003813                  0.026480
#
# H2OBinomialMetrics: glm
# ** Reported on training data. **
#
# MSE:  0.1376967
# RMSE:  0.371075
# LogLoss:  0.4375107
# Mean Per-Class Error:  0.351009
# AUC:  0.700834
# Gini:  0.401668
# R^2:  0.0771224
# Residual Deviance:  100501.5
# AIC:  100613.5
#
# Confusion Matrix (vertical: actual; across: predicted) for F1-optimal threshold:
#            0     1    Error           Rate
# 0      61002 32891 0.350303   =32891/93893
# 1       7373 13590 0.351715    =7373/20963
# Totals 68375 46481 0.350561  =40264/114856
#
# Maximum Metrics: Maximum metrics at their respective thresholds
#                         metric threshold    value idx
# 1                       max f1  0.183215 0.403001 244
# 2                       max f2  0.106978 0.561545 321
# 3                 max f0point5  0.280181 0.364233 165
# 4                 max accuracy  0.533346 0.817789  42
# 5                max precision  0.822035 1.000000   0
# 6                   max recall  0.001238 1.000000 399
# 7              max specificity  0.822035 1.000000   0
# 8             max absolute_mcc  0.206012 0.235568 224
# 9   max min_per_class_accuracy  0.183215 0.648285 244
# 10 max mean_per_class_accuracy  0.181177 0.649161 246
#
# Gains/Lift Table: Extract with `h2o.gainsLift(<model>, <data>)` or `h2o.gainsLift(<model>, valid=<T/F>, xval=<T/F>)`
# H2OBinomialMetrics: glm
# ** Reported on validation data. **
#
# MSE:  0.1390718
# RMSE:  0.3729233
# LogLoss:  0.4412427
# Mean Per-Class Error:  0.3605455
# AUC:  0.6963712
# Gini:  0.3927424
# R^2:  0.07476601
# Residual Deviance:  43357.39
# AIC:  43469.39
#
# Confusion Matrix (vertical: actual; across: predicted) for F1-optimal threshold:
#            0     1    Error          Rate
# 0      28873 11205 0.279580  =11205/40078
# 1       3997  5056 0.441511    =3997/9053
# Totals 32870 16261 0.309418  =15202/49131
#
# Maximum Metrics: Maximum metrics at their respective thresholds
#                         metric threshold    value idx
# 1                       max f1  0.206013 0.399463 221
# 2                       max f2  0.104740 0.563480 320
# 3                 max f0point5  0.277128 0.364162 162
# 4                 max accuracy  0.548735 0.816328  31
# 5                max precision  0.662931 0.666667   8
# 6                   max recall  0.001360 1.000000 399
# 7              max specificity  0.756261 0.999950   0
# 8             max absolute_mcc  0.216979 0.231417 211
# 9   max min_per_class_accuracy  0.182181 0.640651 243
# 10 max mean_per_class_accuracy  0.171230 0.643319 255
#
# Gains/Lift Table: Extract with `h2o.gainsLift(<model>, <data>)` or `h2o.gainsLift(<model>, valid=<T/F>, xval=<T/F>)`

# %%
# print sorted, non-zero model parameters
coef <- as.data.frame(h2o.coef(loan_glm))
names(coef) <- "coef"
coef <- coef[order(-coef$coef), , drop = FALSE]
coef <- coef[coef$coef != 0, , drop = FALSE] 
coef
# Out:
#                            coef
# purpose.small_business      6.629662e-01
# addr_state.NV               2.388950e-01
# addr_state.TN               2.180882e-01
# purpose.educational         2.054414e-01
# addr_state.FL               1.881469e-01
# term.60 months              1.533837e-01
# addr_state.MI               1.432021e-01
# addr_state.NJ               1.334593e-01
# addr_state.OK               1.321407e-01
# addr_state.AL               1.081745e-01
# int_rate                    9.999462e-02
# addr_state.LA               9.483106e-02
# addr_state.RI               8.775709e-02
# addr_state.KY               8.735143e-02
# addr_state.NY               7.759990e-02
# addr_state.MO               7.210391e-02
# purpose.other               5.935341e-02
# addr_state.MA               5.849942e-02
# home_ownership.RENT         4.425038e-02
# purpose.medical             3.663190e-02
# delinq_2yrs                 3.603056e-02
# addr_state.GA               3.582061e-02
# addr_state.IN               2.617202e-02
# dti                         2.245445e-02
# revol_util                  4.211867e-03
# longest_credit_length       3.812768e-03
# addr_state.CA               2.803242e-03
# loan_amnt                   1.246969e-05
# annual_inc                 -6.360862e-06
# total_acc                  -9.485430e-03
# addr_state.KS              -1.869757e-02
# addr_state.AZ              -2.315390e-02
# addr_state.UT              -3.203535e-02
# home_ownership.OWN         -3.692235e-02
# addr_state.WA              -4.651256e-02
# addr_state.VA              -5.457979e-02
# addr_state.HI              -6.445055e-02
# addr_state.MT              -7.080017e-02
# addr_state.MN              -7.676303e-02
# addr_state.SC              -8.229481e-02
# purpose.major_purchase     -9.049152e-02
# home_ownership.MORTGAGE    -1.082128e-01
# addr_state.TX              -1.120831e-01
# addr_state.WI              -1.168793e-01
# addr_state.OR              -1.204883e-01
# purpose.debt_consolidation -1.337402e-01
# addr_state.DC              -1.411338e-01
# addr_state.AK              -1.422044e-01
# purpose.car                -1.623820e-01
# addr_state.CO              -2.131888e-01
# term.36 months             -2.162792e-01
# purpose.credit_card        -2.342808e-01
# purpose.wedding            -2.556101e-01
# addr_state.WY              -3.009996e-01
# addr_state.WV              -3.366287e-01
# Intercept                  -2.891055e+00

# %%
h2o.shutdown(prompt = FALSE)
# Out:
# [1] TRUE
