# %%
import h2o

# %%
h2o.init()
# Out:
# ERROR:h2o:Key init.version_check is not a valid config key
# Checking whether there is an H2O instance running at http://localhost:54321. connected.
# --------------------------  ----------------------------------------
# H2O cluster uptime:         2 hours 18 mins
# H2O cluster version:        3.14.0.7
# H2O cluster version age:    13 days
# H2O cluster name:           avkashchauhan
# H2O cluster total nodes:    1
# H2O cluster free memory:    6.666 Gb
# H2O cluster total cores:    8
# H2O cluster allowed cores:  8
# H2O cluster status:         locked, healthy
# H2O connection url:         http://localhost:54321
# H2O connection proxy:
# H2O internal security:      False
# H2O API Extensions:         XGBoost, Algos, AutoML, Core V3, Core V4
# Python version:             2.7.13 final
# --------------------------  ----------------------------------------

# %%
h2o.cluster_info()
# Out:
# [WARNING] in <ipython-input-3-543db3df6d2d> line 1:
#     >>> h2o.cluster_info()
#         ^^^^ Deprecated, use ``h2o.cluster().show_status()``.
# --------------------------  ----------------------------------------
# H2O cluster uptime:         2 hours 18 mins
# H2O cluster version:        3.14.0.7
# H2O cluster version age:    13 days
# H2O cluster name:           avkashchauhan
# H2O cluster total nodes:    1
# H2O cluster free memory:    6.666 Gb
# H2O cluster total cores:    8
# H2O cluster allowed cores:  8
# H2O cluster status:         locked, healthy
# H2O connection url:         http://localhost:54321
# H2O connection proxy:
# H2O internal security:      False
# H2O API Extensions:         XGBoost, Algos, AutoML, Core V3, Core V4
# Python version:             2.7.13 final
# --------------------------  ----------------------------------------

# %%
h2o.cluster_status()
# Out:
# [WARNING] in <ipython-input-4-f797d33662e0> line 1:
#     >>> h2o.cluster_status()
#         ^^^^ Deprecated, use ``h2o.cluster().show_status(True)``.
# --------------------------  ----------------------------------------
# H2O cluster uptime:         2 hours 18 mins
# H2O cluster version:        3.14.0.7
# H2O cluster version age:    13 days
# H2O cluster name:           avkashchauhan
# H2O cluster total nodes:    1
# H2O cluster free memory:    6.666 Gb
# H2O cluster total cores:    8
# H2O cluster allowed cores:  8
# H2O cluster status:         locked, healthy
# H2O connection url:         http://localhost:54321
# H2O connection proxy:
# H2O internal security:      False
# H2O API Extensions:         XGBoost, Algos, AutoML, Core V3, Core V4
# Python version:             2.7.13 final
# --------------------------  ----------------------------------------
# Nodes info:     Node 1
# --------------  --------------------
# h2o             /10.224.104.92:54321
# healthy         True
# ...

# %%
df = h2o.import_file("https://raw.githubusercontent.com/h2oai/h2o-tutorials/master/training/ceder-rapids/prostate.csv")
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%

# %%
df.summary()
# Out:
# <table>
# <thead>
# <tr><th>       </th><th>ID           </th><th>CAPSULE       </th><th>AGE          </th><th>RACE          </th><th>DPROS        </th><th>DCAPS         </th><th>PSA          </th><th>VOL          </th><th>GLEASON      </th></tr>
# </thead>
# <tbody>
# <tr><td>type   </td><td>int          </td><td>int           </td><td>int          </td><td>int           </td><td>int          </td><td>int           </td><td>real         </td><td>real         </td><td>int          </td></tr>
# <tr><td>mins   </td><td>1.0          </td><td>0.0           </td><td>43.0         </td><td>0.0           </td><td>1.0          </td><td>1.0           </td><td>0.3          </td><td>0.0          </td><td>0.0          </td></tr>
# <tr><td>mean   </td><td>190.5        </td><td>0.402631578947</td><td>66.0394736842</td><td>1.08684210526 </td><td>2.27105263158</td><td>1.10789473684 </td><td>15.4086315789</td><td>15.8129210526</td><td>6.38421052632</td></tr>
# ...

# %%
df.head(5)
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  ID</th><th style="text-align: right;">  CAPSULE</th><th style="text-align: right;">  AGE</th><th style="text-align: right;">  RACE</th><th style="text-align: right;">  DPROS</th><th style="text-align: right;">  DCAPS</th><th style="text-align: right;">  PSA</th><th style="text-align: right;">  VOL</th><th style="text-align: right;">  GLEASON</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">   1</td><td style="text-align: right;">        0</td><td style="text-align: right;">   65</td><td style="text-align: right;">     1</td><td style="text-align: right;">      2</td><td style="text-align: right;">      1</td><td style="text-align: right;">  1.4</td><td style="text-align: right;">  0  </td><td style="text-align: right;">        6</td></tr>
# ...

# %%
df.tail(5)
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  ID</th><th style="text-align: right;">  CAPSULE</th><th style="text-align: right;">  AGE</th><th style="text-align: right;">  RACE</th><th style="text-align: right;">  DPROS</th><th style="text-align: right;">  DCAPS</th><th style="text-align: right;">  PSA</th><th style="text-align: right;">  VOL</th><th style="text-align: right;">  GLEASON</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;"> 376</td><td style="text-align: right;">        0</td><td style="text-align: right;">   58</td><td style="text-align: right;">     2</td><td style="text-align: right;">      3</td><td style="text-align: right;">      1</td><td style="text-align: right;"> 18.2</td><td style="text-align: right;"> 28.6</td><td style="text-align: right;">        7</td></tr>
# ...

# %%
df.describe()
# Out:
# Rows:380
# Cols:9
# <table>
# <thead>
# <tr><th>       </th><th>ID           </th><th>CAPSULE       </th><th>AGE          </th><th>RACE          </th><th>DPROS        </th><th>DCAPS         </th><th>PSA          </th><th>VOL          </th><th>GLEASON      </th></tr>
# </thead>
# <tbody>
# <tr><td>type   </td><td>int          </td><td>int           </td><td>int          </td><td>int           </td><td>int          </td><td>int           </td><td>real         </td><td>real         </td><td>int          </td></tr>
# <tr><td>mins   </td><td>1.0          </td><td>0.0           </td><td>43.0         </td><td>0.0           </td><td>1.0          </td><td>1.0           </td><td>0.3          </td><td>0.0          </td><td>0.0          </td></tr>
# <tr><td>mean   </td><td>190.5        </td><td>0.402631578947</td><td>66.0394736842</td><td>1.08684210526 </td><td>2.27105263158</td><td>1.10789473684 </td><td>15.4086315789</td><td>15.8129210526</td><td>6.38421052632</td></tr>
# ...

# %%
df.head()
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  ID</th><th style="text-align: right;">  CAPSULE</th><th style="text-align: right;">  AGE</th><th style="text-align: right;">  RACE</th><th style="text-align: right;">  DPROS</th><th style="text-align: right;">  DCAPS</th><th style="text-align: right;">  PSA</th><th style="text-align: right;">  VOL</th><th style="text-align: right;">  GLEASON</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">   1</td><td style="text-align: right;">        0</td><td style="text-align: right;">   65</td><td style="text-align: right;">     1</td><td style="text-align: right;">      2</td><td style="text-align: right;">      1</td><td style="text-align: right;">  1.4</td><td style="text-align: right;">  0  </td><td style="text-align: right;">        6</td></tr>
# ...

# %%
df.tail()
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  ID</th><th style="text-align: right;">  CAPSULE</th><th style="text-align: right;">  AGE</th><th style="text-align: right;">  RACE</th><th style="text-align: right;">  DPROS</th><th style="text-align: right;">  DCAPS</th><th style="text-align: right;">  PSA</th><th style="text-align: right;">  VOL</th><th style="text-align: right;">  GLEASON</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;"> 371</td><td style="text-align: right;">        1</td><td style="text-align: right;">   74</td><td style="text-align: right;">     1</td><td style="text-align: right;">      3</td><td style="text-align: right;">      1</td><td style="text-align: right;">  6  </td><td style="text-align: right;">  0  </td><td style="text-align: right;">        5</td></tr>
# ...

# %%
df.sd()
# Out:
# [109.84079387914127,
#  0.4910743389630552,
#  6.527071269173311,
#  0.3087732580252793,
#  1.0001076181502861,
#  0.3106564493514939,
#  19.99757266856046,
#  18.347619967271175,
#  1.0919533744261092]

# %%
type(df)
# Out:
# h2o.frame.H2OFrame

# %%
import pylab as pl
df.as_data_frame().hist()
pl.show()

# %%
df.hist
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  ID</th><th style="text-align: right;">  CAPSULE</th><th style="text-align: right;">  AGE</th><th style="text-align: right;">  RACE</th><th style="text-align: right;">  DPROS</th><th style="text-align: right;">  DCAPS</th><th style="text-align: right;">  PSA</th><th style="text-align: right;">  VOL</th><th style="text-align: right;">  GLEASON</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">   1</td><td style="text-align: right;">        0</td><td style="text-align: right;">   65</td><td style="text-align: right;">     1</td><td style="text-align: right;">      2</td><td style="text-align: right;">      1</td><td style="text-align: right;">  1.4</td><td style="text-align: right;">  0  </td><td style="text-align: right;">        6</td></tr>
# ...

# %%
df.type
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  ID</th><th style="text-align: right;">  CAPSULE</th><th style="text-align: right;">  AGE</th><th style="text-align: right;">  RACE</th><th style="text-align: right;">  DPROS</th><th style="text-align: right;">  DCAPS</th><th style="text-align: right;">  PSA</th><th style="text-align: right;">  VOL</th><th style="text-align: right;">  GLEASON</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">   1</td><td style="text-align: right;">        0</td><td style="text-align: right;">   65</td><td style="text-align: right;">     1</td><td style="text-align: right;">      2</td><td style="text-align: right;">      1</td><td style="text-align: right;">  1.4</td><td style="text-align: right;">  0  </td><td style="text-align: right;">        6</td></tr>
# ...

# %%
df.shape
# Out:
# (380, 9)

# %%
df.col_names
# Out:
# [u'ID',
#  u'CAPSULE',
#  u'AGE',
#  u'RACE',
#  u'DPROS',
#  u'DCAPS',
#  u'PSA',
#  u'VOL',
#  u'GLEASON']

# %%
print(df['CAPSULE'].unique())
print(df['DPROS'].levels)
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  C1</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">   0</td></tr>
# <tr><td style="text-align: right;">   1</td></tr>
# </tbody>
# </table>
# <table>
# <thead>
# <tr><th style="text-align: right;">  DPROS</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">      2</td></tr>
# <tr><td style="text-align: right;">      3</td></tr>
# <tr><td style="text-align: right;">      1</td></tr>
# <tr><td style="text-align: right;">      2</td></tr>
# <tr><td style="text-align: right;">      1</td></tr>
# <tr><td style="text-align: right;">      3</td></tr>
# <tr><td style="text-align: right;">      4</td></tr>
# <tr><td style="text-align: right;">      4</td></tr>
# <tr><td style="text-align: right;">      1</td></tr>
# <tr><td style="text-align: right;">      1</td></tr>
# </tbody>
# </table>
# <bound method H2OFrame.levels of >

# %% [markdown]
# ## Generalized Liner Model : Linear Regression

# %%
y = 'CAPSULE'
x = df.col_names
x.remove(y)

# %%
print("Response = " + y)
print("Pridictors = " + str(x))
# Out:
# Response = CAPSULE
# Pridictors = [u'ID', u'AGE', u'RACE', u'DPROS', u'DCAPS', u'PSA', u'VOL', u'GLEASON']

# %%
from h2o.estimators.glm import H2OGeneralizedLinearEstimator

# %%
glm = H2OGeneralizedLinearEstimator()

# %%
glm.train(x= x, y = y, training_frame=df)
# Out:
# glm Model Build progress: |███████████████████████████████████████████████| 100%

# %%
print(glm)
# Out:
# Model Details
# ...
# H2OGeneralizedLinearEstimator :  Generalized Linear Modeling
# Model Key:  GLM_model_python_1509724873145_1146
#
#
# ModelMetricsRegressionGLM: glm
# ** Reported on train data. **
#
# MSE: 0.171166559131
# RMSE: 0.413722804702
# MAE: 0.360095170207
# RMSLE: 0.298422968136
# R^2: 0.288346113315
# Mean Residual Deviance: 0.171166559131
# Null degrees of freedom: 379
# Residual degrees of freedom: 371
# Null deviance: 91.3973684211
# Residual deviance: 65.0432924697
# AIC: 427.648381952
# Scoring History:
#     timestamp            duration    iterations    negative_log_likelihood    objective
# --  -------------------  ----------  ------------  -------------------------  -----------
#     2017-11-03 11:27:07  0.000 sec   0             91.3974                    0.240519

# %%
glm.model_performance(train=True)
# Out:
# ModelMetricsRegressionGLM: glm
# ** Reported on train data. **
#
# MSE: 0.171166559131
# RMSE: 0.413722804702
# MAE: 0.360095170207
# RMSLE: 0.298422968136
# R^2: 0.288346113315
# Mean Residual Deviance: 0.171166559131
# Null degrees of freedom: 379
# Residual degrees of freedom: 371
# Null deviance: 91.3973684211
# Residual deviance: 65.0432924697
# AIC: 427.648381952

# %%
glm.model_performance(valid=True)

# %%
print(glm.rmse())
print(glm.mse())
print(glm.r2())
# Out:
# 0.413722804702
# 0.171166559131
# 0.288346113315

# %%
glm.coef()
# Out:
# {u'AGE': -0.0011331492033401125,
#  u'DCAPS': 0.1085073577337114,
#  u'DPROS': 0.09233430643683936,
#  u'GLEASON': 0.15140493476895678,
#  u'ID': 0.0002737401477708327,
#  u'Intercept': -0.8055753037768821,
#  u'PSA': 0.0036139417439959207,
#  u'RACE': -0.0818370556607493,
#  u'VOL': -0.0020465387634969107}

# %%
train, valid = df.split_frame(ratios=[.9])

# %%
print(df.shape)
print(train.shape)
print(valid.shape)
# Out:
# (380, 9)
# (343, 9)
# (37, 9)

# %%
train, valid, test = df.split_frame(ratios=[.8, .1])

# %%
print(df.shape)
print(train.shape)
print(valid.shape)
print(test.shape)
# Out:
# (380, 9)
# (308, 9)
# (28, 9)
# (44, 9)

# %%
glm_with_valid = H2OGeneralizedLinearEstimator()

# %%
glm_with_valid.train(x= x, y = y, training_frame=train, validation_frame=valid)
# Out:
# glm Model Build progress: |███████████████████████████████████████████████| 100%

# %%
glm_with_valid
# Out:
# Model Details
# ...
# H2OGeneralizedLinearEstimator :  Generalized Linear Modeling
# Model Key:  GLM_model_python_1509724873145_1147
#
#
# ModelMetricsRegressionGLM: glm
# ** Reported on train data. **
#
# MSE: 0.169296332131
# RMSE: 0.411456355075
# MAE: 0.353500298528
# RMSLE: 0.298139266964
# R^2: 0.29022286422
# Mean Residual Deviance: 0.169296332131
# Null degrees of freedom: 307
# Residual degrees of freedom: 299
# Null deviance: 73.4642857143
# Residual deviance: 52.1432702964
# AIC: 347.025902719
#
# ModelMetricsRegressionGLM: glm
# ** Reported on validation data. **
#
# MSE: 0.17267374824
# RMSE: 0.415540308803
# MAE: 0.358845738082
# RMSLE: 0.381078535866
# R^2: 0.276063002031
# Mean Residual Deviance: 0.17267374824
# Null degrees of freedom: 27
# Residual degrees of freedom: 19
# Null deviance: 6.67857142857
# Residual deviance: 4.83486495072
# AIC: 50.2827210882
# Scoring History:
#     timestamp            duration    iterations    negative_log_likelihood    objective
# ...

# %%
print(glm_with_valid.model_performance(test_data=test).rmse())
print(glm_with_valid.model_performance(test_data=valid).rmse())
print(glm_with_valid.model_performance(test_data=train).rmse())
# Out:
# 0.432733345339
# 0.415540308803
# 0.411456355075

# %%
print(glm_with_valid.model_performance(test_data=test).r2())
print(glm_with_valid.model_performance(test_data=valid).r2())
print(glm_with_valid.model_performance(test_data=train).r2())
# Out:
# 0.249416615209
# 0.276063002031
# 0.29022286422

# %%
glm_with_valid.coef()
# Out:
# {u'AGE': 0.00017950240855501393,
#  u'DCAPS': 0.0997521663750162,
#  u'DPROS': 0.09231141034484117,
#  u'GLEASON': 0.16575830069654066,
#  u'ID': 0.0002798392445315572,
#  u'Intercept': -0.9796998321884804,
#  u'PSA': 0.0029233223671414543,
#  u'RACE': -0.07871821159156903,
#  u'VOL': -0.001960663136725075}

# %%
df_pred = glm_with_valid.predict(test_data=test)
# Out:
# glm prediction progress: |████████████████████████████████████████████████| 100%

# %%
df_pred
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">   predict</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">0.611399  </td></tr>
# <tr><td style="text-align: right;">0.255676  </td></tr>
# <tr><td style="text-align: right;">0.00202222</td></tr>
# <tr><td style="text-align: right;">0.481504  </td></tr>
# <tr><td style="text-align: right;">0.379668  </td></tr>
# <tr><td style="text-align: right;">0.937576  </td></tr>
# <tr><td style="text-align: right;">0.0696653 </td></tr>
# <tr><td style="text-align: right;">0.0761928 </td></tr>
# <tr><td style="text-align: right;">0.359304  </td></tr>
# <tr><td style="text-align: right;">0.658172  </td></tr>
# </tbody>
# </table>

# %%
glm_with_valid.model_performance(test_data=test)
# Out:
# ModelMetricsRegressionGLM: glm
# ** Reported on test data. **
#
# MSE: 0.187258148168
# RMSE: 0.432733345339
# MAE: 0.376004021815
# RMSLE: 0.294216018369
# R^2: 0.249416615209
# Mean Residual Deviance: 0.187258148168
# Null degrees of freedom: 43
# Residual degrees of freedom: 35
# Null deviance: 11.2908163265
# Residual deviance: 8.23935851941
# AIC: 71.154836647

# %% [markdown]
# ## Generalized Linear Model : Logistic Regression

# %%
df['CAPSULE'].summary()
# Out:
# <table>
# <thead>
# <tr><th>       </th><th>CAPSULE       </th></tr>
# </thead>
# <tbody>
# <tr><td>type   </td><td>int           </td></tr>
# <tr><td>mins   </td><td>0.0           </td></tr>
# <tr><td>mean   </td><td>0.402631578947</td></tr>
# <tr><td>maxs   </td><td>1.0           </td></tr>
# <tr><td>sigma  </td><td>0.491074338963</td></tr>
# <tr><td>zeros  </td><td>227           </td></tr>
# <tr><td>missing</td><td>0             </td></tr>
# <tr><td>0      </td><td>0.0           </td></tr>
# <tr><td>1      </td><td>0.0           </td></tr>
# <tr><td>2      </td><td>0.0           </td></tr>
# <tr><td>3      </td><td>0.0           </td></tr>
# <tr><td>4      </td><td>0.0           </td></tr>
# <tr><td>5      </td><td>1.0           </td></tr>
# <tr><td>6      </td><td>0.0           </td></tr>
# <tr><td>7      </td><td>0.0           </td></tr>
# <tr><td>8      </td><td>0.0           </td></tr>
# <tr><td>9      </td><td>0.0           </td></tr>
# </tbody>
# </table>

# %%
df['CAPSULE'] = df['CAPSULE'].asfactor()

# %%
df['CAPSULE'].summary()
# Out:
# <table>
# <thead>
# <tr><th>       </th><th>CAPSULE  </th></tr>
# </thead>
# <tbody>
# <tr><td>type   </td><td>enum     </td></tr>
# <tr><td>mins   </td><td>         </td></tr>
# <tr><td>mean   </td><td>         </td></tr>
# <tr><td>maxs   </td><td>         </td></tr>
# <tr><td>sigma  </td><td>         </td></tr>
# <tr><td>zeros  </td><td>         </td></tr>
# <tr><td>missing</td><td>0        </td></tr>
# <tr><td>0      </td><td>0        </td></tr>
# <tr><td>1      </td><td>0        </td></tr>
# <tr><td>2      </td><td>0        </td></tr>
# <tr><td>3      </td><td>0        </td></tr>
# <tr><td>4      </td><td>0        </td></tr>
# <tr><td>5      </td><td>1        </td></tr>
# <tr><td>6      </td><td>0        </td></tr>
# <tr><td>7      </td><td>0        </td></tr>
# <tr><td>8      </td><td>0        </td></tr>
# <tr><td>9      </td><td>0        </td></tr>
# </tbody>
# </table>

# %%
df['CAPSULE'].levels()
# Out:
# [['0', '1']]

# %%
train, valid, test = df.split_frame(ratios=[.8,.1])

# %%
glm_logistic = H2OGeneralizedLinearEstimator(family = "binomial")

# %%
glm_logistic.train(x=x, y= y, training_frame=train, validation_frame=valid, 
                   model_id="glm_logistic"
                  )
# Out:
# glm Model Build progress: |███████████████████████████████████████████████| 100%

# %%
glm_logistic
# Out:
# Model Details
# ...
# H2OGeneralizedLinearEstimator :  Generalized Linear Modeling
# Model Key:  glm_logistic
#
#
# ModelMetricsBinomialGLM: glm
# ** Reported on train data. **
#
# MSE: 0.164807434237
# RMSE: 0.405964818964
# LogLoss: 0.496858914949
# Null degrees of freedom: 306
# Residual degrees of freedom: 298
# Null deviance: 415.685551149
# Residual deviance: 305.071373779
# AIC: 323.071373779
# AUC: 0.830658598614
# Gini: 0.661317197229
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.335477016338:
#        0    1    Error    Rate
# -----  ---  ---  -------  ------------
# 0      127  54   0.2983   (54.0/181.0)
# 1      24   102  0.1905   (24.0/126.0)
# Total  151  156  0.2541   (78.0/307.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
# metric                       threshold    value     idx
# ---------------------------  -----------  --------  -----
# max f1                       0.335477     0.723404  155
# ...

# %%
glm_logistic.varimp()

# %%
glm_logistic.confusion_matrix()
# Out:
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.335477016338:
#        0    1    Error    Rate
# -----  ---  ---  -------  ------------
# 0      127  54   0.2983   (54.0/181.0)
# 1      24   102  0.1905   (24.0/126.0)
# Total  151  156  0.2541   (78.0/307.0)

# %%
glm_logistic.predict(test_data=test)
# Out:
# glm prediction progress: |████████████████████████████████████████████████| 100%
# <table>
# <thead>
# <tr><th style="text-align: right;">  predict</th><th style="text-align: right;">       p0</th><th style="text-align: right;">      p1</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">        1</td><td style="text-align: right;">0.0436078</td><td style="text-align: right;">0.956392</td></tr>
# <tr><td style="text-align: right;">        0</td><td style="text-align: right;">0.798073 </td><td style="text-align: right;">0.201927</td></tr>
# <tr><td style="text-align: right;">        1</td><td style="text-align: right;">0.0139546</td><td style="text-align: right;">0.986045</td></tr>
# <tr><td style="text-align: right;">        1</td><td style="text-align: right;">0.0457992</td><td style="text-align: right;">0.954201</td></tr>
# <tr><td style="text-align: right;">        1</td><td style="text-align: right;">0.702339 </td><td style="text-align: right;">0.297661</td></tr>
# ...

# %% [markdown]
# ## Gradient Boosting Model

# %%
from h2o.estimators.gbm import H2OGradientBoostingEstimator

# %%
gbm = H2OGradientBoostingEstimator()

# %%
gbm.train(x=x, y =y, training_frame=train, validation_frame=valid)
# Out:
# gbm Model Build progress: |███████████████████████████████████████████████| 100%

# %%
gbm
# Out:
# Model Details
# ...
# H2OGradientBoostingEstimator :  Gradient Boosting Machine
# Model Key:  GBM_model_python_1509724873145_10546
#
#
# ModelMetricsBinomial: gbm
# ** Reported on train data. **
#
# MSE: 0.0602899442882
# RMSE: 0.24554010729
# LogLoss: 0.23494071914
# Mean Per-Class Error: 0.0466105410857
# AUC: 0.989125668684
# Gini: 0.978251337367
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.401994493059:
#        0    1    Error    Rate
# -----  ---  ---  -------  ------------
# 0      167  14   0.0773   (14.0/181.0)
# 1      2    124  0.0159   (2.0/126.0)
# Total  169  138  0.0521   (16.0/307.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
# metric                       threshold    value     idx
# ---------------------------  -----------  --------  -----
# max f1                       0.401994     0.939394  137
# max f2                       0.401994     0.965732  137
# max f0point5                 0.542865     0.953608  113
# ...

# %%
gbm.confusion_matrix()
# Out:
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.401994493059:
#        0    1    Error    Rate
# -----  ---  ---  -------  ------------
# 0      167  14   0.0773   (14.0/181.0)
# 1      2    124  0.0159   (2.0/126.0)
# Total  169  138  0.0521   (16.0/307.0)

# %%
gbm.varimp()
# Out:
# [(u'GLEASON', 77.72722625732422, 1.0, 0.2700459365608598),
#  (u'PSA', 58.766963958740234, 0.7560666549991888, 0.2041727279516924),
#  (u'ID', 47.0581169128418, 0.6054264275049634, 0.16349294663427336),
#  (u'VOL', 33.3232421875, 0.4287203312412034, 0.11577418337271281),
#  (u'DPROS', 31.712934494018555, 0.4080029099331234, 0.11017952793244642),
#  (u'AGE', 29.091629028320312, 0.37427849196637214, 0.10107238589764521),
#  (u'DCAPS', 8.744085311889648, 0.11249707127000039, 0.03037937697146105),
#  (u'RACE', 1.4054476022720337, 0.018081792827897274, 0.004882914678908957)]

# %%
gbm.varimp_plot()

# %% [markdown]
# ## Machine learning with cross validation

# %%
from h2o.estimators.gbm import H2OGradientBoostingEstimator

# %%
gbm_cv3 = H2OGradientBoostingEstimator(nfolds=3)

# %%
gbm_cv3.train(x=x, y=y, training_frame=df)
# Out:
# gbm Model Build progress: |███████████████████████████████████████████████| 100%

# %%
gbm_cv3
# Out:
# Model Details
# ...
# H2OGradientBoostingEstimator :  Gradient Boosting Machine
# Model Key:  GBM_model_python_1509724873145_10751
#
#
# ModelMetricsBinomial: gbm
# ** Reported on train data. **
#
# MSE: 0.0637863025683
# RMSE: 0.252559503025
# LogLoss: 0.244491796997
# Mean Per-Class Error: 0.0581900895454
# AUC: 0.98825256975
# Gini: 0.976505139501
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.369290229047:
#        0    1    Error    Rate
# -----  ---  ---  -------  ------------
# 0      208  19   0.0837   (19.0/227.0)
# 1      5    148  0.0327   (5.0/153.0)
# Total  213  167  0.0632   (24.0/380.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
# metric                       threshold    value     idx
# ---------------------------  -----------  --------  -----
# max f1                       0.36929      0.925     166
# max f2                       0.328487     0.955414  172
# max f0point5                 0.570988     0.947137  131
# ...

# %%
gbm_cv3.cross_validation_predictions()

# %%
gbm_cv4 = H2OGradientBoostingEstimator(keep_cross_validation_predictions = True, nfolds=4)

# %%
gbm_cv4.train(x=x, y=y, training_frame=train)
# Out:
# gbm Model Build progress: |███████████████████████████████████████████████| 100%

# %%
gbm_cv4.cross_validation_predictions()
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  predict</th><th style="text-align: right;">       p0</th><th style="text-align: right;">      p1</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">        0</td><td style="text-align: right;">0.898094 </td><td style="text-align: right;">0.101906</td></tr>
# <tr><td style="text-align: right;">        0</td><td style="text-align: right;">0        </td><td style="text-align: right;">0       </td></tr>
# <tr><td style="text-align: right;">        1</td><td style="text-align: right;">0.0943888</td><td style="text-align: right;">0.905611</td></tr>
# <tr><td style="text-align: right;">        0</td><td style="text-align: right;">0        </td><td style="text-align: right;">0       </td></tr>
# <tr><td style="text-align: right;">        1</td><td style="text-align: right;">0.496563 </td><td style="text-align: right;">0.503437</td></tr>
# ...

# %% [markdown]
# ## Random Forest

# %%
from h2o.estimators.random_forest import H2ORandomForestEstimator

# %%
drf = H2ORandomForestEstimator(nfolds=5, keep_cross_validation_predictions=True)

# %%
drf.train(x=x, y = y, training_frame=train)
# Out:
# drf Model Build progress: |███████████████████████████████████████████████| 100%

# %%
drf
# Out:
# Model Details
# ...
# H2ORandomForestEstimator :  Distributed Random Forest
# Model Key:  DRF_model_python_1509724873145_13113
#
#
# ModelMetricsBinomial: drf
# ** Reported on train data. **
#
# MSE: 0.182714548139
# RMSE: 0.427451223111
# LogLoss: 0.653176774598
# Mean Per-Class Error: 0.259778128563
# AUC: 0.79187494519
# Gini: 0.58374989038
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.352941176471:
#        0    1    Error    Rate
# -----  ---  ---  -------  ------------
# 0      120  61   0.337    (61.0/181.0)
# 1      23   103  0.1825   (23.0/126.0)
# Total  143  164  0.2736   (84.0/307.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
# metric                       threshold    value     idx
# ---------------------------  -----------  --------  -----
# max f1                       0.352941     0.710345  114
# max f2                       0.222222     0.818182  144
# max f0point5                 0.535714     0.702247  69
# ...

# %%
drf.confusion_matrix()
# Out:
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.352941176471:
#        0    1    Error    Rate
# -----  ---  ---  -------  ------------
# 0      120  61   0.337    (61.0/181.0)
# 1      23   103  0.1825   (23.0/126.0)
# Total  143  164  0.2736   (84.0/307.0)

# %%
drf.gains_lift()
# Out:
# Gains/Lift Table: Avg response rate: 41.04 %
#     group    cumulative_data_fraction    lower_threshold    lift      cumulative_lift    response_rate    cumulative_response_rate    capture_rate    cumulative_capture_rate    gain      cumulative_gain
# --  -------  --------------------------  -----------------  --------  -----------------  ---------------  --------------------------  --------------  -------------------------  --------  -----------------
#     1        0.0162866                   1                  2.43651   2.43651            1                1                           0.0396825       0.0396825                  143.651   143.651
#     2        0.0423453                   0.98               2.43651   2.43651            1                1                           0.0634921       0.103175                   143.651   143.651
# ...

# %% [markdown]
# ## Deep Learning

# %%
from h2o.estimators.deeplearning import H2ODeepLearningEstimator

# %%
##random_fold = random.randint(3,10)
dl_model = H2ODeepLearningEstimator(nfolds=5,fold_assignment="Modulo",hidden=[10,10],epochs=10)

# %%
dl_model.train(x=x, y=y, training_frame=train)
# Out:
# deeplearning Model Build progress: |██████████████████████████████████████| 100%

# %%
dl_model
# Out:
# Model Details
# ...
# H2ODeepLearningEstimator :  Deep Learning
# Model Key:  DeepLearning_model_python_1509724873145_27510
#
#
# ModelMetricsBinomial: deeplearning
# ** Reported on train data. **
#
# MSE: 0.150119850197
# RMSE: 0.387453029665
# LogLoss: 0.4632965448
# Mean Per-Class Error: 0.199859686048
# AUC: 0.858019819346
# Gini: 0.716039638692
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.417046732764:
#        0    1    Error    Rate
# -----  ---  ---  -------  ------------
# 0      146  35   0.1934   (35.0/181.0)
# 1      26   100  0.2063   (26.0/126.0)
# Total  172  135  0.1987   (61.0/307.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
# metric                       threshold    value     idx
# ---------------------------  -----------  --------  -----
# max f1                       0.417047     0.766284  134
# max f2                       0.143014     0.833333  233
# max f0point5                 0.463188     0.765472  121
# ...

# %% [markdown]
# ## AutoML

# %%
from h2o.automl import H2OAutoML

# %%
aml = H2OAutoML(max_runtime_secs=30)

# %%
aml.train(x=x, y = y, training_frame=train)
# Out:
# AutoML progress: |████████████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%

# %%
aml.leaderboard
# Out:
# <table>
# <thead>
# <tr><th>model_id                                  </th><th style="text-align: right;">     auc</th><th style="text-align: right;">  logloss</th></tr>
# </thead>
# <tbody>
# <tr><td>DL_grid_0_AutoML_20171103_122226_model_0  </td><td style="text-align: right;">0.761218</td><td style="text-align: right;"> 0.638856</td></tr>
# <tr><td>GBM_grid_1_AutoML_20171103_122226_model_14</td><td style="text-align: right;">0.759615</td><td style="text-align: right;"> 0.708416</td></tr>
# <tr><td>GBM_grid_1_AutoML_20171103_122226_model_20</td><td style="text-align: right;">0.75641 </td><td style="text-align: right;"> 1.27924 </td></tr>
# <tr><td>GLM_grid_0_AutoML_20171103_122226_model_1 </td><td style="text-align: right;">0.75641 </td><td style="text-align: right;"> 0.592638</td></tr>
# <tr><td>GLM_grid_0_AutoML_20171103_122226_model_0 </td><td style="text-align: right;">0.75641 </td><td style="text-align: right;"> 0.592638</td></tr>
# ...

# %%
aml.leader
# Out:
# Model Details
# ...
# H2ODeepLearningEstimator :  Deep Learning
# Model Key:  DL_grid_0_AutoML_20171103_122226_model_0
#
#
# ModelMetricsBinomial: deeplearning
# ** Reported on train data. **
#
# MSE: 0.18376704421
# RMSE: 0.428680585296
# LogLoss: 0.550446722828
# Mean Per-Class Error: 0.242938931298
# AUC: 0.809828244275
# Gini: 0.61965648855
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.18530416275:
#        0    1    Error    Rate
# -----  ---  ---  -------  ------------
# 0      87   44   0.3359   (44.0/131.0)
# 1      12   68   0.15     (12.0/80.0)
# Total  99   112  0.2654   (56.0/211.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
# metric                       threshold    value     idx
# ---------------------------  -----------  --------  -----
# max f1                       0.185304     0.708333  111
# max f2                       0.0665423    0.810526  154
# max f0point5                 0.501213     0.68662   50
# ...

# %%
aml.leader.auc()
# Out:
# 0.8098282442748092

# %%
aml.leader.confusion_matrix()
# Out:
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.18530416275:
#        0    1    Error    Rate
# -----  ---  ---  -------  ------------
# 0      87   44   0.3359   (44.0/131.0)
# 1      12   68   0.15     (12.0/80.0)
# Total  99   112  0.2654   (56.0/211.0)

# %%
aml.leader.predict(test_data=test)
# Out:
# deeplearning prediction progress: |███████████████████████████████████████| 100%
# <table>
# <thead>
# <tr><th style="text-align: right;">  predict</th><th style="text-align: right;">       p0</th><th style="text-align: right;">       p1</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">        1</td><td style="text-align: right;">0.219646 </td><td style="text-align: right;">0.780354 </td></tr>
# <tr><td style="text-align: right;">        1</td><td style="text-align: right;">0.839621 </td><td style="text-align: right;">0.160379 </td></tr>
# <tr><td style="text-align: right;">        1</td><td style="text-align: right;">0.0442069</td><td style="text-align: right;">0.955793 </td></tr>
# <tr><td style="text-align: right;">        1</td><td style="text-align: right;">0.0722716</td><td style="text-align: right;">0.927728 </td></tr>
# ...

# %%
aml.leader.model_performance(test_data=test)
# Out:
# ModelMetricsBinomial: deeplearning
# ** Reported on test data. **
#
# MSE: 0.181572408326
# RMSE: 0.426113140288
# LogLoss: 0.565328073543
# Mean Per-Class Error: 0.261363636364
# AUC: 0.75
# Gini: 0.5
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.312931483027:
#        0    1    Error    Rate
# -----  ---  ---  -------  ----------
# 0      15   5    0.25     (5.0/20.0)
# 1      3    8    0.2727   (3.0/11.0)
# Total  18   13   0.2581   (8.0/31.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
# metric                       threshold    value     idx
# ---------------------------  -----------  --------  -----
# max f1                       0.312931     0.666667  12
# max f2                       0.0329185    0.763889  27
# max f0point5                 0.692815     0.714286  5
# max accuracy                 0.692815     0.774194  5
# max precision                0.955793     1         0
# max recall                   0.0329185    1         27
# ...

# %% [markdown]
# ## Tree Visualization

# %%
mojo_file_name = "/Users/avkashchauhan/Downloads/my_rf_001.zip"
my_rf.download_mojo(mojo_file_name)

# %%
import subprocess
from IPython.display import Image

def generateTree(h2o_jar_path, mojo_full_path, gv_file_path, image_file_path, tree_id = 0):
    result = subprocess.call(["java",  "-cp", h2o_jar_path, "hex.genmodel.tools.PrintMojo", "--tree", str(tree_id), "-i",  mojo_full_path , "-o", gv_file_path ], shell=False)
    result = subprocess.call(["ls",gv_file_path], shell = False) # change "ls" to "dir" if using windows
    if result is 0:
        print("Success: Graphviz file " + gv_file_path + " is generated.")
    else:    
        print("Error: Graphviz file " + gv_file_path + " could not be generated.")
        

# -------------------        
# I had to do in 2 steps. If I put all in 1 step the process hung after graphviz is created. Still investigating
# -------------------
def displayTreeImage(gv_file_path, image_file_path):
    result = subprocess.call(["dot", "-Tpng", gv_file_path, "-o", image_file_path], shell=False)
    result = subprocess.call(["ls",image_file_path], shell = False)
    if result is 0:
        print("Success: Image File " + image_file_path + " is generated.")
        print("Now you can execute the follow line as-it-is to see the tree graph:") 
        print("Image(filename='" + image_file_path + "\')")
    else:
        print("Error: Image file " + image_file_path + " could not be generated.")
    
#Call above function with various parameters

# %%
h2o_jar_path= '/Users/avkashchauhan/tools/h2o-3/h2o-3.14.0.3/h2o.jar'
mojo_full_path = mojo_file_name
gv_file_path = "/Users/avkashchauhan/Downloads/my_rf__000.gv"
image_file_path = "/Users/avkashchauhan/Downloads/my_rf_001.png"

# %%
# Note just change the tree id in the function below to get which particular tree you want
generateTree(h2o_jar_path, mojo_full_path, gv_file_path, image_file_path, 1)

# %%
displayTreeImage(gv_file_path, image_file_path)
# Note: If this step hangs, you can look at "dot" active process in osx and try killing it

# %%
Image(filename='/Users/avkashchauhan/Downloads/my_rf_001.png')
